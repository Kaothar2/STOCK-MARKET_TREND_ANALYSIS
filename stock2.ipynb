# %% [markdown]
# ### Import Necessary Libraries

# %%
# !pip install mlflow #xgboost tensorflow sklearn pandas numpy
# !pip install keras_tuner
# !pip install pyngrok
# Out:
# Collecting mlflow
#   Downloading mlflow-2.21.3-py3-none-any.whl.metadata (30 kB)
# Collecting mlflow-skinny==2.21.3 (from mlflow)
#   Downloading mlflow_skinny-2.21.3-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.1.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.1.6)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.8)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.10.0)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.11/dist-packages (from mlflow) (2.0.2)
# Requirement already satisfied: pandas<3 in /usr/local/lib/python3.11/dist-packages (from mlflow) (2.2.2)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow) (18.1.0)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.11/dist-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.11/dist-packages (from mlflow) (1.14.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow) (2.0.40)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (3.1.1)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.21.3->mlflow)
#   Downloading databricks_sdk-0.50.0-py3-none-any.whl.metadata (38 kB)
# Collecting fastapi<1 (from mlflow-skinny==2.21.3->mlflow)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (8.6.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (1.32.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (1.32.1)
# Requirement already satisfied: packaging<25 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (24.2)
# Requirement already satisfied: protobuf<6,>=3.12.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (5.29.4)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (2.11.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (4.13.2)
# Collecting uvicorn<1 (from mlflow-skinny==2.21.3->mlflow)
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic!=1.10.0,<2->mlflow) (1.1.3)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from docker<8,>=4.0.0->mlflow) (2.3.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow) (1.9.0)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from graphene<4->mlflow) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2<4,>=2.11->mlflow) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.0)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.11/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.3->mlflow) (2.38.0)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi<1->mlflow-skinny==2.21.3->mlflow)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.21.3->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.21.3->mlflow) (3.21.0)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.21.3->mlflow) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.21.3->mlflow) (0.53b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.21.3->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.21.3->mlflow) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.21.3->mlflow) (0.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.21.3->mlflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.21.3->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.21.3->mlflow) (2025.1.31)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn<1->mlflow-skinny==2.21.3->mlflow) (0.14.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.21.3->mlflow) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.21.3->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.3->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.3->mlflow) (4.9.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.21.3->mlflow) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.21.3->mlflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.3->mlflow) (0.6.1)
# Downloading mlflow-2.21.3-py3-none-any.whl (28.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.2/28.2 MB 28.1 MB/s eta 0:00:00
# Downloading mlflow_skinny-2.21.3-py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 64.5 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 7.1 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 6.2 MB/s eta 0:00:00
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 5.8 MB/s eta 0:00:00
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 2.6 MB/s eta 0:00:00
# Downloading databricks_sdk-0.50.0-py3-none-any.whl (692 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 692.3/692.3 kB 23.7 MB/s eta 0:00:00
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 1.8 MB/s eta 0:00:00
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 10.5 MB/s eta 0:00:00
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 3.1 MB/s eta 0:00:00
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: uvicorn, gunicorn, graphql-core, starlette, graphql-relay, docker, alembic, graphene, fastapi, databricks-sdk, mlflow-skinny, mlflow
# Successfully installed alembic-1.15.2 databricks-sdk-0.50.0 docker-7.1.0 fastapi-0.115.12 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 gunicorn-23.0.0 mlflow-2.21.3 mlflow-skinny-2.21.3 starlette-0.46.2 uvicorn-0.34.2
# Collecting keras_tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (3.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (2.32.3)
# Collecting kt-legacy (from keras_tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (0.15.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (2025.1.31)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras->keras_tuner) (4.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras_tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras_tuner) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras_tuner) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.2 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras_tuner
# Successfully installed keras_tuner-1.4.7 kt-legacy-1.0.5
# Collecting pyngrok
#   Downloading pyngrok-7.2.4-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pyngrok) (6.0.2)
# Downloading pyngrok-7.2.4-py3-none-any.whl (23 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.2.4

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

import numpy as np
from datetime import datetime

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import keras_tuner as kt

from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

import mlflow
import mlflow.sklearn
import mlflow.keras
from mlflow.models.signature import infer_signature
import shap

from sklearn.metrics import accuracy_score
import xgboost as xgb
from xgboost import Booster

from pyngrok import ngrok
import subprocess
import time

import pickle
import os

sns.set_style('darkgrid')
sns.set_palette('muted')
sns.set_context("notebook", font_scale=1.5,
                rc={"lines.linewidth": 2.5})

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Extraction
#
# We will extract data for primary stock = PepsiCo (PEP), Competitor stock = Coca-Cola (KO), and the market indexS&P 500 (^GSPC) for the past 4 years.

# %%
end = datetime.now() #(2024, 12, 2)
start = datetime(end.year - 4, end.month, end.day)

# Define the stock tickers
primary_stock = 'PEP'  # PepsiCo
competitor_stock = 'KO'  # Coca-Cola

bench_mark_index = '^GSPC' #S&P 500

# %%
pep_data = yf.download(primary_stock, start, end)

pep_data.head()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open   Volume
# Ticker             PEP         PEP         PEP         PEP      PEP
# Date
# 2021-04-21  130.898468  131.628756  130.212726  131.227994  6316000
# 2021-04-22  130.088058  130.604587  129.473551  130.239457  4904400
# 2021-04-23  129.874268  130.328462  129.188512  129.589273  4354700
# 2021-04-26  127.674522  129.820840  127.336095  129.624910  5817700
# 2021-04-27  127.255936  127.514200  126.579095  127.015473  4693700

# %%
co_data = yf.download(competitor_stock, start, end)

co_data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker             KO         KO         KO         KO        KO
# Date
# 2021-04-21  48.415092  48.530346  48.087066  48.087066  13866500
# 2021-04-22  48.264378  48.645599  48.157991  48.290977  12558900
# 2021-04-23  48.290977  48.397364  48.025006  48.228918   9020500
# 2021-04-26  47.572857  48.326432  47.501934  48.290972  11684600
# 2021-04-27  47.501934  47.608320  47.271426  47.484202   9852400

# %%
index_data = yf.download(bench_mark_index, start, end)

index_data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open      Volume
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC       ^GSPC
# Date
# 2021-04-21  4173.419922  4175.020020  4126.350098  4128.419922  3887250000
# 2021-04-22  4134.979980  4179.569824  4123.689941  4170.459961  4245140000
# 2021-04-23  4180.169922  4194.169922  4138.779785  4138.779785  3569880000
# 2021-04-26  4187.620117  4194.189941  4182.359863  4185.029785  3748320000
# 2021-04-27  4186.720215  4193.350098  4176.220215  4188.250000  3710700000

# %% [markdown]
# Create adjClose Feature from CLose Column

# %%
# Feature Engineering Function
def add_adjclose(adjclose):
    # Adj Close
    adjclose['Adj Close'] = adjclose['Close']

# Apply the function
add_adjclose(pep_data)
add_adjclose(co_data)
add_adjclose(index_data)

# %%
pep_data.head(2)
# Out:
# Price            Close        High         Low        Open   Volume  \
# Ticker             PEP         PEP         PEP         PEP      PEP
# Date
# 2021-04-21  130.898468  131.628756  130.212726  131.227994  6316000
# 2021-04-22  130.088058  130.604587  129.473551  130.239457  4904400
#
# Price        Adj Close
# Ticker
# Date
# 2021-04-21  130.898468
# 2021-04-22  130.088058

# %%
co_data.head(2)
# Out:
# Price           Close       High        Low       Open    Volume  Adj Close
# Ticker             KO         KO         KO         KO        KO
# Date
# 2021-04-21  48.415092  48.530346  48.087066  48.087066  13866500  48.415092
# 2021-04-22  48.264378  48.645599  48.157991  48.290977  12558900  48.264378

# %%
index_data.head(2)
# Out:
# Price             Close         High          Low         Open      Volume  \
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC       ^GSPC
# Date
# 2021-04-21  4173.419922  4175.020020  4126.350098  4128.419922  3887250000
# 2021-04-22  4134.979980  4179.569824  4123.689941  4170.459961  4245140000
#
# Price         Adj Close
# Ticker
# Date
# 2021-04-21  4173.419922
# 2021-04-22  4134.979980

# %% [markdown]
# ## Feature Engineering
# Adding features such as ,  (next day's adjusted close price), and  (binary indicator for price movement direction).

# %%
# Feature Engineering Function
def add_features(data):
    # Daily Return
    data['Daily Return'] = data['Adj Close'].pct_change()
    # Tomorrow's Price
    data['Tomorrow'] = data['Adj Close'].shift(-1)
    # Stock Direction (1 = Price went up, 0 = Price went down)
    data['Stock Direction'] = (data['Tomorrow'] > data['Adj Close']).astype(int)

# Apply the function
add_features(pep_data)
add_features(co_data)
add_features(index_data)

# %% [markdown]
# ### Preview the updated data

# %%
pep_data.head(2)
# Out:
# Price            Close        High         Low        Open   Volume  \
# Ticker             PEP         PEP         PEP         PEP      PEP
# Date
# 2021-04-21  130.898468  131.628756  130.212726  131.227994  6316000
# 2021-04-22  130.088058  130.604587  129.473551  130.239457  4904400
#
# Price        Adj Close Daily Return    Tomorrow Stock Direction
# Ticker
# Date
# 2021-04-21  130.898468          NaN  130.088058               0
# 2021-04-22  130.088058    -0.006191  129.874268               0

# %%
co_data.head(2)
# Out:
# Price           Close       High        Low       Open    Volume  Adj Close  \
# Ticker             KO         KO         KO         KO        KO
# Date
# 2021-04-21  48.415092  48.530346  48.087066  48.087066  13866500  48.415092
# 2021-04-22  48.264378  48.645599  48.157991  48.290977  12558900  48.264378
#
# Price      Daily Return   Tomorrow Stock Direction
# Ticker
# Date
# 2021-04-21          NaN  48.264378               0
# 2021-04-22    -0.003113  48.290977               1

# %%
index_data.head(2)
# Out:
# Price             Close         High          Low         Open      Volume  \
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC       ^GSPC
# Date
# 2021-04-21  4173.419922  4175.020020  4126.350098  4128.419922  3887250000
# 2021-04-22  4134.979980  4179.569824  4123.689941  4170.459961  4245140000
#
# Price         Adj Close Daily Return     Tomorrow Stock Direction
# Ticker
# Date
# 2021-04-21  4173.419922          NaN  4134.979980               0
# 2021-04-22  4134.979980    -0.009211  4180.169922               1

# %% [markdown]
# ## Exploratory Data Analysis
#
# Investigate historical trends, returns, and volatility for each stock.
#
# ### 1. Historical Trends
# Visualizing the Adjusted Close prices over time.

# %%
plt.figure(figsize=(15, 8))
plt.plot(pep_data['Adj Close'], label='PEP', color='blue')
plt.plot(co_data['Adj Close'], label='KO', color='red')
plt.plot(index_data['Adj Close'], label='S&P 500', color='green')
plt.title('Historical Trends of Stock Prices')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')
plt.legend()
#plt.grid(True)
plt.show()

# %% [markdown]
# Daily Returns overtime

# %%
# Add daily returns to a single DataFrame for visualization
pep_data['Type'] = 'PEP'
co_data['Type'] = 'KO'
index_data['Type'] = 'S&P 500'

# Reset index to make 'Date' a column
pep_data = pep_data.reset_index()
co_data = co_data.reset_index()
index_data = index_data.reset_index()

daily_returns = pd.concat([pep_data[['Date', 'Daily Return', 'Type']],
                           co_data[['Date', 'Daily Return', 'Type']],
                           index_data[['Date', 'Daily Return', 'Type']]])

# %%
print(type(daily_returns.columns))
print(daily_returns.columns)
# Out:
# <class 'pandas.core.indexes.multi.MultiIndex'>
# MultiIndex([(        'Date', ''),
#             ('Daily Return', ''),
#             (        'Type', '')],
#            names=['Price', 'Ticker'])

# %%
daily_returns.columns = ['Date', 'Daily Return', 'Type']

# %%
# Create an interactive line plot
fig_returns = px.line(
    daily_returns,
    x='Date',
    y='Daily Return',
    color='Type',
    title='Daily Return Trends Over Time',
    labels={'Daily Return': 'Daily Return', 'Date': 'Date'}
)
fig_returns.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="20e7c50e-204d-417b-b0f2-ceb80b3744da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20e7c50e-204d-417b-b0f2-ceb80b3744da")) {                    Plotly.newPlot(                        "20e7c50e-204d-417b-b0f2-ceb80b3744da",                        [{"hovertemplate":"Type=PEP\u003cbr\u003eDate=%{x}\u003cbr\u003eDaily Return=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PEP","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"PEP","showlegend":true,"x":["2021-04-21T00:00:00","2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-13T00:00:00","2021-05-14T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-19T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00","2021-05-28T00:00:00","2021-06-01T00:00:00","2021-06-02T00:00:00","2021-06-03T00:00:00","2021-06-04T00:00:00","2021-06-07T00:00:00","2021-06-08T00:00:00","2021-06-09T00:00:00","2021-06-10T00:00:00","2021-06-11T00:00:00","2021-06-14T00:00:00","2021-06-15T00:00:00","2021-06-16T00:00:00","2021-06-17T00:00:00","2021-06-18T00:00:00","2021-06-21T00:00:00","2021-06-22T00:00:00","2021-06-23T00:00:00","2021-06-24T00:00:00","2021-06-25T00:00:00","2021-06-28T00:00:00","2021-06-29T00:00:00","2021-06-30T00:00:00","2021-07-01T00:00:00","2021-07-02T00:00:00","2021-07-06T00:00:00","2021-07-07T00:00:00","2021-07-08T00:00:00","2021-07-09T00:00:00","2021-07-12T00:00:00","2021-07-13T00:00:00","2021-07-14T00:00:00","2021-07-15T00:00:00","2021-07-16T00:00:00","2021-07-19T00:00:00","2021-07-20T00:00:00","2021-07-21T00:00:00","2021-07-22T00:00:00","2021-07-23T00:00:00","2021-07-26T00:00:00","2021-07-27T00:00:00","2021-07-28T00:00:00","2021-07-29T00:00:00","2021-07-30T00:00:00","2021-08-02T00:00:00","2021-08-03T00:00:00","2021-08-04T00:00:00","2021-08-05T00:00:00","2021-08-06T00:00:00","2021-08-09T00:00:00","2021-08-10T00:00:00","2021-08-11T00:00:00","2021-08-12T00:00:00","2021-08-13T00:00:00","2021-08-16T00:00:00","2021-08-17T00:00:00","2021-08-18T00:00:00","2021-08-19T00:00:00","2021-08-20T00:00:00","2021-08-23T00:00:00","2021-08-24T00:00:00","2021-08-25T00:00:00","2021-08-26T00:00:00","2021-08-27T00:00:00","2021-08-30T00:00:00","2021-08-31T00:00:00","2021-09-01T00:00:00","2021-09-02T00:00:00","2021-09-03T00:00:00","2021-09-07T00:00:00","2021-09-08T00:00:00","2021-09-09T00:00:00","2021-09-10T00:00:00","2021-09-13T00:00:00","2021-09-14T00:00:00","2021-09-15T00:00:00","2021-09-16T00:00:00","2021-09-17T00:00:00","2021-09-20T00:00:00","2021-09-21T00:00:00","2021-09-22T00:00:00","2021-09-23T00:00:00","2021-09-24T00:00:00","2021-09-27T00:00:00","2021-09-28T00:00:00","2021-09-29T00:00:00","2021-09-30T00:00:00","2021-10-01T00:00:00","2021-10-04T00:00:00","2021-10-05T00:00:00","2021-10-06T00:00:00","2021-10-07T00:00:00","2021-10-08T00:00:00","2021-10-11T00:00:00","2021-10-12T00:00:00","2021-10-13T00:00:00","2021-10-14T00:00:00","2021-10-15T00:00:00","2021-10-18T00:00:00","2021-10-19T00:00:00","2021-10-20T00:00:00","2021-10-21T00:00:00","2021-10-22T00:00:00","2021-10-25T00:00:00","2021-10-26T00:00:00","2021-10-27T00:00:00","2021-10-28T00:00:00","2021-10-29T00:00:00","2021-11-01T00:00:00","2021-11-02T00:00:00","2021-11-03T00:00:00","2021-11-04T00:00:00","2021-11-05T00:00:00","2021-11-08T00:00:00","2021-11-09T00:00:00","2021-11-10T00:00:00","2021-11-11T00:00:00","202 ...

# %% [markdown]
# Cummulative Returns

# %%
pep_data['Cumulative Return'] = (1 + pep_data['Daily Return'] / 100).cumprod()
co_data['Cumulative Return'] = (1 + co_data['Daily Return'] / 100).cumprod()
index_data['Cumulative Return'] = (1 + index_data['Daily Return'] / 100).cumprod()

plt.figure(figsize=(15, 8))
plt.plot(pep_data['Cumulative Return'], label='PEP', color='blue')
plt.plot(co_data['Cumulative Return'], label='KO', color='red')
plt.plot(index_data['Cumulative Return'], label='S&P 500', color='green')

plt.title('Cumulative Returns of Stock Prices')
plt.xlabel('Date')
plt.ylabel('Cumulative Return')
plt.legend()
plt.show()

# %% [markdown]
# ### Volatility Analysis
# Analyzing the distributions of daily returns.

# %%
pep_volatility = pep_data['Daily Return'].std()
co_volatility = co_data['Daily Return'].std()
index_volatility = index_data['Daily Return'].std()

print(f"Volatility of PEP: {pep_volatility}")
print(f"Volatility of KO: {co_volatility}")
print(f"Volatility of S&P 500: {index_volatility}")
# Out:
# Volatility of PEP: 0.010844692126188295
# Volatility of KO: 0.010007839277724346
# Volatility of S&P 500: 0.011234462986186673

# %%
plt.figure(figsize=(15, 8))

sns.kdeplot(pep_data['Daily Return'].dropna(), label='PEP', fill=True, color='blue')
sns.kdeplot(co_data['Daily Return'].dropna(), label='KO', fill=True, color='red')
sns.kdeplot(index_data['Daily Return'].dropna(), label='S&P 500', fill=True, color='green')

plt.title('Volatility Analysis of Daily Returns')
plt.xlabel('Daily Returns')
plt.legend()
# plt.grid(True)
plt.show()

# %% [markdown]
# KDE plots provide a smooth curve that makes it easier to identify the concentration and spread of returns.
#
# A wider curve means more volatility (more extreme returns), while a narrower curve suggests less volatility
#
# A narrower distribution (concentrated around zero) suggests lower volatility.
#
# A wider distribution indicates higher volatility.

# %% [markdown]
# ### 2. Dynamic Visualizations
#
# Showcasing pricing trends and highlight sector impacts.
#
# ### Dynamic Pricing Trends
# Visualizing trends with overlapping time series.

# %%
plt.figure(figsize=(15, 8))
plt.plot(pep_data['Adj Close'], label='PEP', color='blue')
plt.plot(co_data['Adj Close'], label='KO', color='red')
plt.title('Dynamic Pricing Trends')
plt.legend()
#plt.grid(True)
plt.show()

# %% [markdown]
# ### 3. Comparative Analysis
# ### Correlation Analysis:
# Evaluating relationships between each stock and the benchmark index.

# %%
primary_vs_benchmark_corr = pep_data['Adj Close'].corr(index_data['Adj Close'])
competitor_vs_benchmark_corr = co_data['Adj Close'].corr(index_data['Adj Close'])

print(f"Correlation Between PEP and S&P 500: {primary_vs_benchmark_corr}")
print(f"Correlation Between KO and S&P 500: {competitor_vs_benchmark_corr}")
# Out:
# Correlation Between PEP and S&P 500: 0.04252793744373367
# Correlation Between KO and S&P 500: 0.6596028350466782

# %%
# Calculated correlation values
correlations = pd.DataFrame({
    'Stock': ['PEP', 'KO'],
    'Correlation with S&P 500': [
        pep_data['Adj Close'].corr(index_data['Adj Close']),
        co_data['Adj Close'].corr(index_data['Adj Close'])
    ]
})

# Create a bar plot
fig_corr = px.bar(
    correlations,
    x='Stock',
    y='Correlation with S&P 500',
    title='Correlation with S&P 500',
    text='Correlation with S&P 500',
    labels={'Correlation with S&P 500': 'Correlation Coefficient'}
)
fig_corr.update_traces(texttemplate='%{text:.2f}', textposition='outside')
fig_corr.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="06e2da7a-6fc0-43f5-b95e-236b39b1020a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06e2da7a-6fc0-43f5-b95e-236b39b1020a")) {                    Plotly.newPlot(                        "06e2da7a-6fc0-43f5-b95e-236b39b1020a",                        [{"alignmentgroup":"True","hovertemplate":"Stock=%{x}\u003cbr\u003eCorrelation Coefficient=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[0.04252793744373367,0.6596028350466782],"textposition":"outside","x":["PEP","KO"],"xaxis":"x","y":[0.04252793744373367,0.6596028350466782],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2 ...

# %% [markdown]
# ### Observation
# Comparative Insights:
#
# The results from correlation and volatility analysis provide insights into the suitability of each stock for investment relative to market performance.
#
# PEP has a moderate positive correlation, meaning PEP moves somewhat with the market but also has independent movements.
#
# Ko has a stronger positive correlation, meaning KO tends to follow the movements of the S&P 500 more closely than PEP.
#
# It is more likely to be affected by market-wide events. If the market performs well, KO could benefit more than PEP But if the market crashes, KO might suffer more compared to PEP.
#
# Since PEP has a lower correlation with the market, it could be a better hedge against broader market downturns compared to KO.
#
# If an investor wants stability and lower dependency on the S&P 500, PEP might be a better choice.

# %% [markdown]
# ### 4. Comparative Volatility Analysis:
# Computing the standard deviation of daily returns to assess risk levels.

# %%
primary_volatility = pep_data['Daily Return'].std()
competitor_volatility = co_data['Daily Return'].std()
benchmark_volatility = index_data['Daily Return'].std()

print(f"PEP Daily Return Volatility: {primary_volatility}")
print(f"KO Daily Return Volatility: {competitor_volatility}")
print(f"S&P 500 Daily Return Volatility: {benchmark_volatility}")
# Out:
# PEP Daily Return Volatility: 0.010844692126188295
# KO Daily Return Volatility: 0.010007839277724346
# S&P 500 Daily Return Volatility: 0.011234462986186673

# %%
# Calculated volatility values
volatility = pd.DataFrame({
    'Stock': ['PEP', 'KO', 'S&P 500'],
    'Volatility': [
        pep_data['Daily Return'].std(),
        co_data['Daily Return'].std(),
        index_data['Daily Return'].std()
    ]
})

# Create a bar plot
fig_volatility = px.bar(
    volatility,
    x='Stock',
    y='Volatility',
    title='Daily Return Volatility',
    text='Volatility',
    labels={'Volatility': 'Standard Deviation'}
)
fig_volatility.update_traces(texttemplate='%{text:.4f}', textposition='outside')
fig_volatility.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4e6e5a07-6139-40af-9287-3fbae028b13f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e6e5a07-6139-40af-9287-3fbae028b13f")) {                    Plotly.newPlot(                        "4e6e5a07-6139-40af-9287-3fbae028b13f",                        [{"alignmentgroup":"True","hovertemplate":"Stock=%{x}\u003cbr\u003eStandard Deviation=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[0.010844692126188295,0.010007839277724346,0.011234462986186673],"textposition":"outside","x":["PEP","KO","S&P 500"],"xaxis":"x","y":[0.010844692126188295,0.010007839277724346,0.011234462986186673],"yaxis":"y","type":"bar","texttemplate":"%{text:.4f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pa ...

# %% [markdown]
# ### Observation
#
# PepsiCo’s daily returns fluctuate a little more than Coca-Cola’s. This means PEP has a slightly higher risk in terms of daily price movements.
#
# KO has the lowest daily return volatility of the three, meaning it tends to experience smaller price swings compared to PEP and the S&P 500. This could make KO a more stable stock, which might appeal to risk-averse investors.
#
# Since PEP’s volatility (1.03%) is almost the same as the S&P 500’s, it means PEP moves with the overall market in terms of risk. KO, on the other hand, has lower volatility than both, making it a relatively safer bet in the short term.
#
# If they are willing to take on more risk for potential higher returns, PEP might be the better choice.

# %%
# Compute average returns
volatility_returns = pd.DataFrame({
    'Stock': ['PEP', 'KO', 'S&P 500'],
    'Volatility': [
        pep_data['Daily Return'].std(),
        co_data['Daily Return'].std(),
        index_data['Daily Return'].std()
    ],
    'Avg Return': [
        pep_data['Daily Return'].mean(),
        co_data['Daily Return'].mean(),
        index_data['Daily Return'].mean()
    ]
})

# Create a scatter plot
fig_vol_returns = px.scatter(
    volatility_returns,
    x='Volatility',
    y='Avg Return',
    color='Stock',
    size='Volatility',
    hover_name='Stock',
    title='Volatility vs. Average Daily Return',
    labels={'Volatility': 'Volatility (Standard Deviation)', 'Avg Return': 'Average Return'}
)
fig_vol_returns.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c35df50b-55d6-475c-9461-d9e56da2c75b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c35df50b-55d6-475c-9461-d9e56da2c75b")) {                    Plotly.newPlot(                        "c35df50b-55d6-475c-9461-d9e56da2c75b",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eStock=PEP\u003cbr\u003eVolatility (Standard Deviation)=%{marker.size}\u003cbr\u003eAverage Return=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["PEP"],"legendgroup":"PEP","marker":{"color":"#636efa","size":[0.010844692126188295],"sizemode":"area","sizeref":0.000028086157465466683,"symbol":"circle"},"mode":"markers","name":"PEP","orientation":"v","showlegend":true,"x":[0.010844692126188295],"xaxis":"x","y":[0.0001328000372988381],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eStock=KO\u003cbr\u003eVolatility (Standard Deviation)=%{marker.size}\u003cbr\u003eAverage Return=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["KO"],"legendgroup":"KO","marker":{"color":"#EF553B","size":[0.010007839277724346],"sizemode":"area","sizeref":0.000028086157465466683,"symbol":"circle"},"mode":"markers","name":"KO","orientation":"v","showlegend":true,"x":[0.010007839277724346],"xaxis":"x","y":[0.00044620608743925304],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eStock=S&P 500\u003cbr\u003eVolatility (Standard Deviation)=%{marker.size}\u003cbr\u003eAverage Return=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["S&P 500"],"legendgroup":"S&P 500","marker":{"color":"#00cc96","size":[0.011234462986186673],"sizemode":"area","sizeref":0.000028086157465466683,"symbol":"circle"},"mode":"markers","name":"S&P 500","orientation":"v","showlegend":true,"x":[0.011234462986186673],"xaxis":"x","y":[0.00026474720398731165],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"t ...

# %% [markdown]
# ### Observation
#
# The S&P 500 has both high returns and moderate volatility, making it a better investment option than PEP or KO in terms of risk-adjusted returns.
#
# KO seems safer due to lower volatility, but its lower return might not be appealing to aggressive investors.

# %% [markdown]
# Risk-adjusted returns (Sharpe Ratio) to see which stock gives better returns for the risk taken

# %%
# Assume risk-free rate (R_f) is 0 for simplicity
risk_free_rate = 0

# Compute average daily returns
pep_avg_return = pep_data['Daily Return'].mean()
ko_avg_return = co_data['Daily Return'].mean()

# Compute standard deviation of daily returns (volatility)
pep_volatility = pep_data['Daily Return'].std()
ko_volatility = co_data['Daily Return'].std()

# Compute Sharpe Ratios
pep_sharpe_ratio = (pep_avg_return - risk_free_rate) / pep_volatility
ko_sharpe_ratio = (ko_avg_return - risk_free_rate) / ko_volatility

# Print Results
print(f"PEP Sharpe Ratio: {pep_sharpe_ratio:.2f}")
print(f"KO Sharpe Ratio: {ko_sharpe_ratio:.2f}")

# Visualize the Sharpe Ratios
sharpe_ratios = pd.DataFrame({
    'Stock': ['PEP', 'KO'],
    'Sharpe Ratio': [pep_sharpe_ratio, ko_sharpe_ratio]
})

fig_sharpe = px.bar(
    sharpe_ratios,
    x='Stock',
    y='Sharpe Ratio',
    title='Sharpe Ratio Comparison (Risk-Adjusted Returns)',
    text='Sharpe Ratio',
    labels={'Sharpe Ratio': 'Sharpe Ratio'}
)

fig_sharpe.update_traces(texttemplate='%{text:.2f}', textposition='outside')
fig_sharpe.show()
# Out:
# PEP Sharpe Ratio: 0.01
# KO Sharpe Ratio: 0.04
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3eb95b2b-20dc-44c0-98df-1d2143110378" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3eb95b2b-20dc-44c0-98df-1d2143110378")) {                    Plotly.newPlot(                        "3eb95b2b-20dc-44c0-98df-1d2143110378",                        [{"alignmentgroup":"True","hovertemplate":"Stock=%{x}\u003cbr\u003eSharpe Ratio=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[0.012245625394763033,0.04458565680930025],"textposition":"outside","x":["PEP","KO"],"xaxis":"x","y":[0.012245625394763033,0.04458565680930025],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"typ ...

# %% [markdown]
# Both stocks from Sharpe Ratios, suggesting relatively low risk-adjusted returns
#
# KO outperforms PEP when adjustinf for risk, meaning it might be a better option for investors looking for a balance of returns vs. volatility

# %%
# Compute S&P 500 average daily return and volatility
sp500_avg_return = index_data['Daily Return'].mean()
sp500_volatility = index_data['Daily Return'].std()

# Compute Sharpe Ratio for S&P 500
sp500_sharpe_ratio = (sp500_avg_return - risk_free_rate) / sp500_volatility

# Print Results
print(f"S&P 500 Sharpe Ratio: {sp500_sharpe_ratio:.2f}")

# Visualize all three Sharpe Ratios
sharpe_ratios = pd.DataFrame({
    'Stock': ['PEP', 'KO', 'S&P 500'],
    'Sharpe Ratio': [pep_sharpe_ratio, ko_sharpe_ratio, sp500_sharpe_ratio]
})

fig_sharpe = px.bar(
    sharpe_ratios,
    x='Stock',
    y='Sharpe Ratio',
    title='Sharpe Ratio Comparison (PEP vs KO vs S&P 500)',
    text='Sharpe Ratio',
    labels={'Sharpe Ratio': 'Sharpe Ratio'}
)

fig_sharpe.update_traces(texttemplate='%{text:.2f}', textposition='outside')
fig_sharpe.show()
# Out:
# S&P 500 Sharpe Ratio: 0.02
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7dfbb257-bcce-4925-934c-b0c0978683e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7dfbb257-bcce-4925-934c-b0c0978683e8")) {                    Plotly.newPlot(                        "7dfbb257-bcce-4925-934c-b0c0978683e8",                        [{"alignmentgroup":"True","hovertemplate":"Stock=%{x}\u003cbr\u003eSharpe Ratio=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[0.012245625394763033,0.04458565680930025,0.02356563053461758],"textposition":"outside","x":["PEP","KO","S&P 500"],"xaxis":"x","y":[0.012245625394763033,0.04458565680930025,0.02356563053461758],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"f ...

# %% [markdown]
# ## Analysis Insights/
#
# ### Observations
#
# 1. Historical Trends:
# - The Adjusted Close prices of PepsiCo (PEP), Coca-Cola (KO), and the S&P 500 index (^GSPC) exhibit a steady upward trend over the last four years, indicating overall market growth during this period.
# -There are instances of dips in stock prices, likely corresponding to external economic events or company-specific challenges
#
# 2. Volatility:
# - PEP shows relatively lower volatility compared to KO and S&P 500, which suggests it may be a less risky investment option.
# - KO exhibits moderate volatility, implying a balance between risk and reward.
# - The S&P 500 index demonstrates the highest volatility, reflecting its broader exposure to market fluctuations and external shocks.
#
# 3. Daily Returns:
# - The distribution of daily returns for all three shows typical behavior: a central concentration near zero and some sporadic spikes. PEP’s daily returns distribution is narrower than KO’s, indicating more consistent performance.
#
# 4. Correlation Analysis:
# - Both PEP and KO have positive correlations with the S&P 500, with PEP slightly stronger. This suggests their performance aligns reasonably well with overall market trends.
# - The correlation insights imply that PEP is slightly more in sync with market benchmarks than KO, which is beneficial for predicting future behaviors.
#
# 5. Volatility vs. Returns:
# - PEP’s lower volatility comes with relatively steady returns, indicating it as a stable option for long-term investments.
# - KO’s higher volatility might attract investors looking for a slightly more aggressive strategy, but its average returns are similar to PEP.
# - The S&P 500 offers broader exposure but carries significant volatility, suggesting it’s better suited for diversified portfolios
#
# 6. Stock Directions:
# - The direction analysis highlights that KO has more instances of upward price movement compared to PEP, which may indicate better market confidence in PEP's performance.
#
#
#
# ### Key insights
#  The insights derived include;
# -  Performance vs. Risk Trade-Off
#
# For the both stocks (KO and PEP) KO has the next highest average return with lower volatility, making it a more stable choice.
#
# PEP has high volatility but a low average return, which is not ideal because it suggests more risk without enough reward.
#
# *Implication:*  KO is a better-performing stock compared to PEP, while the S&P 500 provides the highest returns but requires higher risk tolerance.
#
#
# - Market Sensitivity (Correlation with S&P 500)
#
# KO (0.64 correlation) moves more closely with the S&P 500, meaning it follows overall market trends more consistently.
#
# PEP (0.38 correlation) moves more independently, meaning its price swings are more influenced by company-specific factors rather than the overall market.
#
# *Implication:*
#
# KO is a better choice for those who want a stock that aligns with broader market trends.

# %% [markdown]
# ## Recommendations
#
# 1. Investment Strategy:
# - For risk-averse investors, Coca-Cola (KO) appears to be the better option due to its lower volatility and stable upward price trend.
# - PEPSICO (PEP), with its higher volatility, may appeal to those looking for moderate-risk investments with comparable returns.
#
#     ####  Investment Decision Perspective
#     Best for Growth: S&P 500 (highest average return, but also high volatility).
#
#     Best for Stability: KO (steady returns, lower volatility, and moves with the market).
#
#     Most Uncertain/Risky: PEP (high volatility but low average returns, meaning risk is not well compensated).
#
#
# 2. Portfolio Diversification:
# Including the S&P 500 index (^GSPC) in the portfolio can add diversification and broader market exposure, though investors should be prepared to handle greater volatility.
#
#     #### For building a portfolio:
#     - S&P 500 → Best for long-term growth (if you can tolerate volatility).
#
#     - KO → Good for steady returns with less risk.
#
#     - PEP → Might need further investigation since it’s volatile but not offering strong returns.
#
#
# 3. Monitor Market Conditions:
# - Regularly track external factors such as economic events, sector trends, and company-specific updates to align investment decisions with prevailing market conditions.
#
# 4. Focus on Stability:
# - For long-term investment goals, prioritize stocks with lower volatility and consistent returns, such as PepsiCo.

# %% [markdown]
# ## Conclusion
# The exploratory data analysis provides valuable insights into the performance, volatility, and correlation of PepsiCo, Coca-Cola, and the S&P 500 index over the past four years. PEP stands out as a stable investment option with steady returns and less volatility, while KO offers slightly more risk for similar average returns. The S&P 500 index provides exposure to broader market trends but carries higher risk.
# Investors should consider these factors alongside their financial goals and risk appetite. By balancing stability, growth potential, and market exposure, a diversified portfolio can be constructed to optimize returns while minimizing risk. Regular monitoring and analysis are essential for adapting to market fluctuations and ensuring alignment with investment strategies.

# %% [markdown]
# ## **Modeling and Evaluation**
# Modeling and evaluation for predicting stock price movement (stock’s direction).
#
# The entire workflow using XGBoost, LSTM, model fine-tuning, validation, performance evaluation, and tracking with MLflow.
#
#
# Metrics like accuracy, F1-score, and confusion matrices will be used to compare models.

# %% [markdown]
# ### Feature Engineering

# %%
# Function to calculate technical indicators and add target variable
def add_indicators(df):
    # Simple Moving Average (SMA)
    df['SMA_20'] = df['Adj Close'].rolling(window=20).mean()
    df['SMA_50'] = df['Adj Close'].rolling(window=50).mean()

    # Exponential Moving Average (EMA)
    df['EMA_20'] = df['Adj Close'].ewm(span=20, adjust=False).mean()
    df['EMA_50'] = df['Adj Close'].ewm(span=50, adjust=False).mean()

    # Relative Strength Index (RSI)
    delta = df['Adj Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()
    rs = gain / loss
    df['RSI'] = 100 - (100 / (1 + rs))

    # Moving Average Convergence Divergence (MACD)
    short_ema = df['Adj Close'].ewm(span=12, adjust=False).mean()
    long_ema = df['Adj Close'].ewm(span=26, adjust=False).mean()
    df['MACD'] = short_ema - long_ema
    df['Signal_Line'] = df['MACD'].ewm(span=9, adjust=False).mean()

    # Volatility
    df['Volatility'] = df['Daily Return'].rolling(window=20).std()

    # Bollinger Bands (Upper & Lower Bands)
    df['Middle_Band'] = df['Adj Close'].rolling(window=20).mean()
    df['Std_Dev'] = df['Adj Close'].rolling(window=20).std()
    df['Upper_Band'] = df['Middle_Band'] + (2 * df['Std_Dev'])
    df['Lower_Band'] = df['Middle_Band'] - (2 * df['Std_Dev'])


    return df.dropna(inplace=True)

# %%
# Apply indicators to all data
for df in [pep_data, co_data, index_data]:
    add_indicators(df)

# %%
pep_data.head()
# Out:
# Price        Date       Close        High         Low        Open   Volume  \
# Ticker                    PEP         PEP         PEP         PEP      PEP
# 49     2021-06-30  132.922302  133.047895  132.052121  132.258448  4943700
# 50     2021-07-01  132.949219  133.738665  132.715979  132.841572  3997600
# 51     2021-07-02  133.586182  134.366649  133.272193  133.577202  3835500
# 52     2021-07-06  133.783539  134.043690  132.563491  133.729715  4313800
# 53     2021-07-07  134.375610  135.191969  133.666913  133.927064  4225000
#
# Price    Adj Close Daily Return    Tomorrow Stock Direction  ...      EMA_20  \
# Ticker                                                       ...
# 49      132.922302     0.008371  132.949219               1  ...  131.681793
# 50      132.949219     0.000202  133.586182               1  ...  131.802500
# 51      133.586182     0.004791  133.783539               1  ...  131.972374
# 52      133.783539     0.001477  134.375610               1  ...  132.144866
# 53      134.375610     0.004426  134.438400               1  ...  132.357318
#
# Price       EMA_50        RSI      MACD Signal_Line Volatility Middle_Band  \
# Ticker
# 49      131.243897  52.066620  0.196404    0.212890   0.008128  131.945833
# 50      131.310773  51.857303  0.275326    0.225377   0.008093  131.969605
# 51      131.400004  51.253603  0.384834    0.257268   0.008156  132.017600
# 52      131.493476  51.997110  0.481988    0.302212   0.008156  132.079500
# 53      131.606501  60.386020  0.599845    0.361739   0.007857  132.232903
#
# Price    Std_Dev  Upper_Band  Lower_Band
# Ticker
# 49      0.960063  133.865959  130.025707
# 50      0.979513  133.928631  130.010579
# 51      1.035311  134.088221  129.946979
# 52      1.103312  134.286125  129.872875
# 53      1.199435  134.631773  129.834032
#
# [5 rows x 24 columns]

# %%
co_data.head()
# Out:
# Price        Date      Close       High        Low       Open    Volume  \
# Ticker                    KO         KO         KO         KO        KO
# 49     2021-06-30  48.333286  48.395813  48.011719  48.056380  14614200
# 50     2021-07-01  48.199287  48.663773  48.109965  48.538720  13214700
# 51     2021-07-02  48.395809  48.636985  48.235025  48.235025  10604600
# 52     2021-07-06  48.127838  48.315418  47.833067  48.226095  15278200
# 53     2021-07-07  48.520863  48.574458  47.984919  47.984919  14377700
#
# Price   Adj Close Daily Return   Tomorrow Stock Direction  ...     EMA_20  \
# Ticker                                                     ...
# 49      48.333286     0.004642  48.199287               0  ...  48.695314
# 50      48.199287    -0.002772  48.395809               1  ...  48.648073
# 51      48.395809     0.004077  48.127838               0  ...  48.624048
# 52      48.127838    -0.005537  48.520863               1  ...  48.576790
# 53      48.520863     0.008166  48.351154               0  ...  48.571464
#
# Price      EMA_50        RSI      MACD Signal_Line Volatility Middle_Band  \
# Ticker
# 49      48.670609  36.340380 -0.132884   -0.017739   0.008094   48.973063
# 50      48.652126  32.056557 -0.153697   -0.044930   0.008064   48.916615
# 51      48.642075  36.272771 -0.152574   -0.066459   0.007672   48.843396
# 52      48.621908  35.145875 -0.171333   -0.087434   0.007713   48.765644
# 53      48.617946  46.391860 -0.152725   -0.100492   0.007896   48.724832
#
# Price    Std_Dev Upper_Band Lower_Band
# Ticker
# 49      0.590308  50.153678  47.792447
# 50      0.608261  50.133137  47.700093
# 51      0.575982  49.995361  47.691432
# 52      0.561471  49.888586  47.642703
# 53      0.547231  49.819293  47.630370
#
# [5 rows x 24 columns]

# %%
co_data.head().T
# Out:
#                                            49                   50  \
# Price             Ticker
# Date                      2021-06-30 00:00:00  2021-07-01 00:00:00
# Close             KO                48.333286            48.199287
# High              KO                48.395813            48.663773
# Low               KO                48.011719            48.109965
# Open              KO                 48.05638             48.53872
# Volume            KO                 14614200             13214700
# Adj Close                           48.333286            48.199287
# Daily Return                         0.004642            -0.002772
# Tomorrow                            48.199287            48.395809
# Stock Direction                             0                    1
# Type                                       KO                   KO
# Cumulative Return                    0.999995             0.999968
# SMA_20                              48.973063            48.916615
# SMA_50                              48.586329            48.582013
# EMA_20                              48.695314            48.648073
# EMA_50                              48.670609            48.652126
# RSI                                  36.34038            32.056557
# MACD                                -0.132884            -0.153697
# Signal_Line                         -0.017739             -0.04493
# Volatility                           0.008094             0.008064
# Middle_Band                         48.973063            48.916615
# Std_Dev                              0.590308             0.608261
# Upper_Band                          50.153678            50.133137
# Lower_Band                          47.792447            47.700093
#
#                                            51                   52  \
# Price             Ticker
# Date                      2021-07-02 00:00:00  2021-07-06 00:00:00
# Close             KO                48.395809            48.127838
# High              KO                48.636985            48.315418
# Low               KO                48.235025            47.833067
# Open              KO                48.235025            48.226095
# Volume            KO                 10604600             15278200
# Adj Close                           48.395809            48.127838
# Daily Return                         0.004077            -0.005537
# Tomorrow                            48.127838            48.520863
# Stock Direction                             0                    1
# Type                                       KO                   KO
# Cumulative Return                    1.000008             0.999953
# SMA_20                              48.843396            48.765644
# SMA_50                              48.584641            48.581379
# EMA_20                              48.624048             48.57679
# EMA_50                              48.642075            48.621908
# RSI                                 36.272771            35.145875
# MACD                                -0.152574            -0.171333
# Signal_Line                         -0.066459            -0.087434
# Volatility                           0.007672             0.007713
# Middle_Band                         48.843396            48.765644
# Std_Dev                              0.575982             0.561471
# Upper_Band                          49.995361            49.888586
# Lower_Band                          47.691432            47.642703
#
#                                            53
# Price             Ticker
# Date                      2021-07-07 00:00:00
# Close             KO                48.520863
# High              KO                48.574458
# Low               KO                47.984919
# Open              KO                47.984919
# Volume            KO                 14377700
# Adj Close                           48.520863
# Daily Return                         0.008166
# Tomorrow                            48.351154
# Stock Direction                             0
# Type                                       KO
# Cumulative Return                    1.000035
# SMA_20                              48.724832
# SMA_50                              48.600339
# EMA_20                              48.571464
# EMA_50                              48.617946
# RSI                                  46.39186
# MACD                                -0.152725
# Signal_Line                         -0.100492
# Volatility                           0.007896
# Middle_Band                         48.724832
# Std_Dev                              0.547231
# Upper_Band                          49.819293
# Lower_Band                           47.63037

# %% [markdown]
# ### Select Feature Columns needed

# %%
# Define the feature columns and target column
feature_columns = ['High','Volume', 'Adj Close', 'Daily Return', 'Tomorrow', 'Cumulative Return',	'SMA_20', 'EMA_20', 'RSI', 'MACD', 'Signal_Line', 'Volatility', 'Middle_Band', 'Std_Dev']

target_column = 'Stock Direction'

# Function to prepare data for machine learning without dropping NaN rows
def prepare_ml_data(stock_df):
    # Directly select the features and target column
    X = stock_df[feature_columns]
    y = stock_df['Stock Direction']
    # Train-test split (80:20) with stratification
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.2, stratify=y, random_state=42, shuffle=True
    )
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ### Feature Sets

# %%
# Prepare data for each stock
X_train_pep, X_test_pep, y_train_pep, y_test_pep = prepare_ml_data(pep_data)
X_train_ko, X_test_ko, y_train_ko, y_test_ko = prepare_ml_data(co_data)

# %%
# Normalize features using MinMaxScaler
scaler_pep = MinMaxScaler()
X_train_pep_norm = scaler_pep.fit_transform(X_train_pep)
X_test_pep_norm = scaler_pep.transform(X_test_pep)

scaler_ko = MinMaxScaler()
X_train_ko_norm = scaler_ko.fit_transform(X_train_ko)
X_test_ko_norm = scaler_ko.transform(X_test_ko)

# %%
# Get the majority classes for baseline comparison
majority_class_pep = y_train_pep.mode()[0]
majority_class_ko = y_train_ko.mode()[0]

# %%
# Set up MLflow tracking
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %% [markdown]
# ### Set Create Experiment Locally or via ngrok

# %% [markdown]
# #### Locally

# %%
# Set/Create an MLflow experiment;
mlflow.set_tracking_uri("file:///tmp/mlruns")  # Local directory
mlflow.set_experiment("Stock_Direction_Prediction")
# Out:
# 2025/04/21 17:53:28 INFO mlflow.tracking.fluent: Experiment with name 'Stock_Direction_Prediction' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///tmp/mlruns/618726886880898425', creation_time=1745258008223, experiment_id='618726886880898425', last_update_time=1745258008223, lifecycle_stage='active', name='Stock_Direction_Prediction', tags={}>

# %%
# Set/Create an MLflow experiment;
#mlflow.set_tracking_uri("/content/drive/MyDrive/Colab Notebooks/Amdari_Work_Exp_Internship_Cohort/StockMarketTrendAnalysis")
#mlflow.set_experiment("Stock_Direction_Prediction")

# %% [markdown]
# #### Ngrok

# %% [markdown]
# # input your authotoken here, and remove all Hashtags

# %%
#!ngrok input yout authotoken here, and remove all Hashtags

# %%
# Open an ngrok tunnel to the MLflow tracking server port (5000)
#public_url = ngrok.connect(5000)
#print("MLflow UI available at:", public_url)

# Launch the MLflow server in the background
# Here we specify a local sqlite DB to track experiments and a directory for artifact storage.
#mlflow_server_cmd = (
    #"mlflow server --backend-store-uri sqlite:///mlflow.db "
    #"--default-artifact-root ./mlruns --host 0.0.0.0 --port 5000"
#)
# Start the MLflow server as a background process
#process = subprocess.Popen(mlflow_server_cmd.split(), stdout=subprocess.PIPE, stderr=subprocess.PIPE)

# Give the server a moment to start up
#time.sleep(5)

# Configure MLflow to use the public URL provided by ngrok
# Get the public URL as a string
#mlflow.set_tracking_uri(public_url.public_url)  # Use public_url.public_url to get the URL string

#mlflow.set_experiment("Stock_Direction_Prediction")

# %% [markdown]
# ## Train XGBoost Model

# %%
# Enable MLflow autologging for XGBoost models
mlflow.xgboost.autolog()

# %%
# Optional: helper to flatten MultiIndex columns if necessary
def flatten_columns(df):
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = df.columns.get_level_values(0)
    return df

# Ensure training and testing sets have a simple, flat column index
X_train_pep = flatten_columns(X_train_pep)
X_test_pep = flatten_columns(X_test_pep)

# Initialize the model
model_pep_xgb = XGBClassifier()

with mlflow.start_run(run_name="XGB_PEP_Model"):
    # Train the model
    model_pep_xgb.fit(X_train_pep, y_train_pep)

    # Generate predictions and compute accuracy
    y_pred_pep = model_pep_xgb.predict(X_test_pep)
    accuracy_pep_xgb = accuracy_score(y_test_pep, y_pred_pep)
    mlflow.log_metric("accuracy", accuracy_pep_xgb)

    # Baseline comparison (predict the majority class)
    baseline_preds_pep = np.full_like(y_test_pep, fill_value=majority_class_pep)
    baseline_accuracy_pep = accuracy_score(y_test_pep, baseline_preds_pep)
    mlflow.log_metric("baseline_accuracy", baseline_accuracy_pep)

    # Log classification report as an artifact
    report_pep = classification_report(y_test_pep, y_pred_pep)
    with open("classification_report_pep.txt", "w") as f:
        f.write(report_pep)
    mlflow.log_artifact("classification_report_pep.txt")

    # Infer the model signature from training data
    signature = infer_signature(X_train_pep, y_train_pep)

    # Prepare an input example by resetting the index
    input_example = X_train_pep.iloc[:1].reset_index(drop=True)

    # Log the model with signature and input example
    mlflow.sklearn.log_model(
        sk_model=model_pep_xgb,
        artifact_path="xgb_pep_model",
        signature=signature,
        input_example=input_example
    )

    print(f"XGB PEP Model | Accuracy: {accuracy_pep_xgb:.4f} | Baseline Accuracy: {baseline_accuracy_pep:.4f}")

# Save the trained model to a pickle file
pickle_filename = "xgb_pep_model.pkl"
with open(pickle_filename, "wb") as file:
    pickle.dump(model_pep_xgb, file)

# Optionally, log the pickle file as an MLflow artifact
mlflow.log_artifact(pickle_filename)
print(f"Model saved to {pickle_filename}")
# Out:
# XGB PEP Model | Accuracy: 0.8063 | Baseline Accuracy: 0.5236
# Model saved to xgb_pep_model.pkl

# %%
# Extract Booster from the trained PEP model
booster_pep = model_pep_xgb.get_booster()

# Save the model using Booster.save_model
booster_pep.save_model("xgb_pep_model.xgb")
print("PEP XGBoost model saved as 'xgb_pep_model.xgb'")
# Out:
# PEP XGBoost model saved as 'xgb_pep_model.xgb'

# %%
mlflow.end_run()

# %%
# XGBOOST for KO
# Optional helper to flatten MultiIndex columns, if needed
def flatten_columns(df):
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = df.columns.get_level_values(0)
    return df

# Ensure training and testing data have a flat column index
X_train_ko = flatten_columns(X_train_ko)
X_test_ko = flatten_columns(X_test_ko)

model_ko_xgb = XGBClassifier()

with mlflow.start_run(run_name="XGB_KO_Model"):
    # Train the model
    model_ko_xgb.fit(X_train_ko, y_train_ko)

    # Generate predictions and calculate accuracy
    y_pred_ko = model_ko_xgb.predict(X_test_ko)
    accuracy_ko_xgb = accuracy_score(y_test_ko, y_pred_ko)
    mlflow.log_metric("accuracy", accuracy_ko_xgb)

    # Baseline comparison using the majority class
    baseline_preds_ko = np.full_like(y_test_ko, fill_value=majority_class_ko)
    baseline_accuracy_ko = accuracy_score(y_test_ko, baseline_preds_ko)
    mlflow.log_metric("baseline_accuracy", baseline_accuracy_ko)

    # Log the classification report as an artifact
    report_ko = classification_report(y_test_ko, y_pred_ko)
    with open("classification_report_ko.txt", "w") as f:
        f.write(report_ko)
    mlflow.log_artifact("classification_report_ko.txt")

    # Infer the model signature from the training data
    signature = infer_signature(X_train_ko, y_train_ko)

    # Create a clean input example from the training data
    input_example = X_train_ko.iloc[:1].reset_index(drop=True)

    # Log the trained model along with the signature and input example
    mlflow.sklearn.log_model(
        sk_model=model_ko_xgb,
        artifact_path="xgb_ko_model",
        signature=signature,
        input_example=input_example
    )

    print(f"XGB KO Model | Accuracy: {accuracy_ko_xgb:.4f} | Baseline Accuracy: {baseline_accuracy_ko:.4f}")

# Save the trained model to a pickle file
pickle_filename = "xgb_ko_model.pkl"
with open(pickle_filename, "wb") as file:
    pickle.dump(model_ko_xgb, file)

# Optionally, log the pickle file as an MLflow artifact
mlflow.log_artifact(pickle_filename)
print(f"Model saved to {pickle_filename}")
# Out:
# XGB KO Model | Accuracy: 0.7120 | Baseline Accuracy: 0.5393
# Model saved to xgb_ko_model.pkl

# %%
# Extract Booster from the trained XGBoost model
booster_ko = model_ko_xgb.get_booster()

# Save the model using Booster.save_model
booster_ko.save_model("xgb_ko_model.xgb")
print("KO XGBoost model saved as 'xgb_ko_model.xgb'")
# Out:
# KO XGBoost model saved as 'xgb_ko_model.xgb'

# %%
mlflow.end_run()

# %%
# !ngrok tunnels kill
# Out:
# ngrok - tunnel local ports to public URLs and inspect traffic
#
# USAGE:
#   ngrok [command] [flags]
#
# COMMANDS:
#   config          update or migrate ngrok's configuration file
#   http            start an HTTP tunnel
#   tcp             start a TCP tunnel
#   tunnel          start a tunnel for use with a tunnel-group backend
#
# EXAMPLES:
#   ngrok http 80                                                 # secure public URL for port 80 web server
#   ngrok http --url baz.ngrok.dev 8080                           # port 8080 available at baz.ngrok.dev
#   ngrok tcp 22                                                  # tunnel arbitrary TCP traffic to port 22
#   ngrok http 80 --oauth=google --oauth-allow-email=foo@foo.com  # secure your app with oauth
#
# Paid Features:
#   ngrok http 80 --url mydomain.com                              # run ngrok with your own custom domain
#   ngrok http 80 --cidr-allow 2600:8c00::a03c:91ee:fe69:9695/32  # run ngrok with IP policy restrictions
#   Upgrade your account at https://dashboard.ngrok.com/billing/subscription to access paid features
#
# Upgrade your account at https://dashboard.ngrok.com/billing/subscription to access paid features
#
# Flags:
#   -h, --help      help for ngrok
#
# Use "ngrok [command] --help" for more information about a command.

# %% [markdown]
# ## Train LSTM Model

# %%
# Enable MLflow autologging for TensorFlow/Keras models.
mlflow.tensorflow.autolog()

# %%
# Recall this

# Normalize features using MinMaxScaler
scaler_pep = MinMaxScaler()
X_train_pep_norm = scaler_pep.fit_transform(X_train_pep)
X_test_pep_norm = scaler_pep.transform(X_test_pep)

scaler_ko = MinMaxScaler()
X_train_ko_norm = scaler_ko.fit_transform(X_train_ko)
X_test_ko_norm = scaler_ko.transform(X_test_ko)

# Get the majority classes for baseline comparison
majority_class_pep = y_train_pep.mode()[0]
majority_class_ko = y_train_ko.mode()[0]

# %%
# Reshape normalized arrays to 3D for LSTM: (samples, timesteps, features)
X_train_pep_lstm = X_train_pep_norm.reshape((X_train_pep_norm.shape[0], X_train_pep_norm.shape[1], 1))
X_test_pep_lstm = X_test_pep_norm.reshape((X_test_pep_norm.shape[0], X_test_pep_norm.shape[1], 1))

X_train_ko_lstm = X_train_ko_norm.reshape((X_train_ko_norm.shape[0], X_train_ko_norm.shape[1], 1))
X_test_ko_lstm = X_test_ko_norm.reshape((X_test_ko_norm.shape[0], X_test_ko_norm.shape[1], 1))

# %%
# --- Callback Definitions ---
# Early stopping and checkpoint for PEP
early_stopping_pep = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint_pep = ModelCheckpoint('best_model_pep.keras', save_best_only=True, verbose=1)

# Early stopping and checkpoint for KO
early_stopping_ko = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint_ko = ModelCheckpoint('best_model_ko.keras', save_best_only=True, verbose=1)

# %%
# --- LSTM Model Building for PEP ---
lstm_model_pep = Sequential([
    LSTM(50, return_sequences=True, input_shape=(X_train_pep_lstm.shape[1], 1)),
    Dropout(0.2),
    LSTM(50, return_sequences=False),
    Dropout(0.2),
    Dense(25, activation='relu'),
    Dense(1, activation='sigmoid')  # Assuming binary classification
])
lstm_model_pep.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# --- Generate Predictions for the Test Set ---
lstm_predictions_prob_pep = lstm_model_pep.predict(X_test_pep_lstm)  # Generate probabilities
lstm_predictions_pep = (lstm_predictions_prob_pep > 0.5).astype(int).flatten()  # Threshold at 0.5 and flatten to 1D

# --- Evaluate the LSTM Model's Performance ---
print("LSTM Performance for PEP:")
accuracy_pep = accuracy_score(y_test_pep, lstm_predictions_pep)
print(f"Accuracy: {accuracy_pep:.2f}")

# Print the classification report
print(classification_report(y_test_pep, lstm_predictions_pep))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step
# LSTM Performance for PEP:
# Accuracy: 0.52
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        91
#            1       0.52      1.00      0.69       100
#
#     accuracy                           0.52       191
#    macro avg       0.26      0.50      0.34       191
# weighted avg       0.27      0.52      0.36       191

# %%
# --- Log Detailed Evaluation Metrics ---
evaluation_metrics_pep = {
    "accuracy": accuracy_pep,
    "precision": classification_report(y_test_pep, lstm_predictions_pep, output_dict=True)["weighted avg"]["precision"],
    "recall": classification_report(y_test_pep, lstm_predictions_pep, output_dict=True)["weighted avg"]["recall"],
    "f1_score": classification_report(y_test_pep, lstm_predictions_pep, output_dict=True)["weighted avg"]["f1-score"]
}

# Print and log all evaluation metrics
print("Evaluation Metrics for PEP:")
for metric, value in evaluation_metrics_pep.items():
    print(f"{metric.capitalize()}: {value:.2f}")
# Out:
# Evaluation Metrics for PEP:
# Accuracy: 0.52
# Precision: 0.27
# Recall: 0.52
# F1_score: 0.36

# %%
#Optional: Save metrics for further analysis or tracking
metrics_path = "evaluation_metrics_pep.txt"
with open(metrics_path, "w") as f:
    for metric, value in evaluation_metrics_pep.items():
        f.write(f"{metric.capitalize()}: {value:.2f}\n")
print(f"Metrics saved to {metrics_path}")
# Out:
# Metrics saved to evaluation_metrics_pep.txt

# %%
# Define the model architecture
lstm_model_pep_tuned = Sequential([
    LSTM(50, return_sequences=True, input_shape=(X_train_pep_lstm.shape[1], 1)),  # Use actual input shape from your data
    Dense(1, activation="sigmoid")
])

# Build the model explicitly (no need to call build separately if input_shape is provided)
# lstm_model_pep_tuned.build(input_shape=(None, 10, 1))  # This is not necessary anymore

# Compile the model
lstm_model_pep_tuned.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
print("Model built and compiled successfully!")

# Save the model in HDF5 format
lstm_model_pep_tuned.save("best_model_pep_tuned.h5")
print("PEP LSTM model saved successfully (HDF5)!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model built and compiled successfully!
# PEP LSTM model saved successfully (HDF5)!

# %%
# Save the PEP LSTM model in a pickle file
with open("lstm_model_pep.pkl", "wb") as file_pep:
    pickle.dump(lstm_model_pep.get_config(), file_pep)  # Save the model configuration
    pickle.dump(lstm_model_pep.get_weights(), file_pep)  # Save the model weights

print("PEP LSTM model saved as 'lstm_model_pep.pkl'.")
# Out:
# PEP LSTM model saved as 'lstm_model_pep.pkl'.

# %%
# --- LSTM Model Building for KO ---
lstm_model_ko = Sequential([
    LSTM(50, return_sequences=True, input_shape=(X_train_ko_lstm.shape[1], 1)),
    Dropout(0.2),
    LSTM(50, return_sequences=False),
    Dropout(0.2),
    Dense(25, activation='relu'),
    Dense(1, activation='sigmoid')  # Assuming binary classification
])
lstm_model_ko.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# --- Generate Predictions for the Test Set ---
lstm_predictions_prob_ko = lstm_model_ko.predict(X_test_ko_lstm)  # Generate probabilities
lstm_predictions_ko = (lstm_predictions_prob_ko > 0.5).astype(int).flatten()  # Threshold at 0.5 and flatten to 1D
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step

# %%
# --- Evaluate the LSTM Model's Performance ---
print("LSTM Performance for KO:")
accuracy_ko = accuracy_score(y_test_ko, lstm_predictions_ko)
print(f"Accuracy: {accuracy_ko:.2f}")

# Print the classification report
print(classification_report(y_test_ko, lstm_predictions_ko))
# Out:
# LSTM Performance for KO:
# Accuracy: 0.47
#               precision    recall  f1-score   support
#
#            0       0.46      1.00      0.63        88
#            1       1.00      0.01      0.02       103
#
#     accuracy                           0.47       191
#    macro avg       0.73      0.50      0.33       191
# weighted avg       0.75      0.47      0.30       191

# %%
# --- Log Detailed Evaluation Metrics ---
evaluation_metrics_ko = {
    "accuracy": accuracy_ko,
    "precision": classification_report(y_test_ko, lstm_predictions_ko, output_dict=True)["weighted avg"]["precision"],
    "recall": classification_report(y_test_ko, lstm_predictions_ko, output_dict=True)["weighted avg"]["recall"],
    "f1_score": classification_report(y_test_ko, lstm_predictions_ko, output_dict=True)["weighted avg"]["f1-score"]
}

# Print and log all evaluation metrics
print("Evaluation Metrics for KO:")
for metric, value in evaluation_metrics_ko.items():
    print(f"{metric.capitalize()}: {value:.2f}")
# Out:
# Evaluation Metrics for KO:
# Accuracy: 0.47
# Precision: 0.75
# Recall: 0.47
# F1_score: 0.30

# %%
# Optional: Save metrics for further analysis or tracking
metrics_path_ko = "evaluation_metrics_ko.txt"
with open(metrics_path_ko, "w") as f:
    for metric, value in evaluation_metrics_ko.items():
        f.write(f"{metric.capitalize()}: {value:.2f}\n")
print(f"Metrics saved to {metrics_path_ko}")
# Out:
# Metrics saved to evaluation_metrics_ko.txt

# %%
# Define the model architecture
lstm_model_ko_tuned = Sequential([
    LSTM(50, return_sequences=True, input_shape=(X_train_pep_lstm.shape[1], 1)),  # Use actual input shape from your data
    Dense(1, activation="sigmoid")
])

# Build the model explicitly (no need to call build separately if input_shape is provided)
# lstm_model_ko_tuned.build(input_shape=(None, 10, 1))  # This is not necessary anymore

# Compile the model
lstm_model_ko_tuned.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
print("Model built and compiled successfully!")

# Save the model in HDF5 format
lstm_model_ko_tuned.save("best_model_ko_tuned.h5")
print("KO LSTM model saved successfully (HDF5)!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model built and compiled successfully!
# KO LSTM model saved successfully (HDF5)!

# %%
# Save the KO LSTM model in a pickle file
with open("lstm_model_ko.pkl", "wb") as file_ko:
    pickle.dump(lstm_model_ko.get_config(), file_ko)
    pickle.dump(lstm_model_ko.get_weights(), file_ko)

print("KO LSTM model saved as 'lstm_model_ko.pkl'.")
# Out:
# KO LSTM model saved as 'lstm_model_ko.pkl'.

# %% [markdown]
# ### Fine-Tuning XGBoost
# Use grid search to optimize hyperparameters.

# %%
mlflow.set_tracking_uri("file:///tmp/mlruns")  # Local directory
mlflow.set_experiment("Stock_Direction_Prediction")
# Out:
# <Experiment: artifact_location='file:///tmp/mlruns/618726886880898425', creation_time=1745258008223, experiment_id='618726886880898425', last_update_time=1745258008223, lifecycle_stage='active', name='Stock_Direction_Prediction', tags={}>

# %%
# --- Helper to flatten MultiIndex columns if necessary ---
def flatten_columns(df):
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = df.columns.get_level_values(0)
    return df

# Ensure training and testing sets have a flat column index
X_train_pep = flatten_columns(X_train_pep)
X_test_pep = flatten_columns(X_test_pep)

# --- Hyperparameter Tuning ---
# Define parameter grid for GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.8, 1.0]
}

# Initialize the base XGBoost model
base_xgb_model = XGBClassifier()

# Perform grid search with cross-validation
grid_search = GridSearchCV(
    estimator=base_xgb_model,
    param_grid=param_grid,
    scoring='accuracy',
    cv=3,  # 3-fold cross-validation
    verbose=1
)
grid_search.fit(X_train_pep, y_train_pep)
best_xgb_model = grid_search.best_estimator_

# Log the best configuration separately
best_params = grid_search.best_params_
accuracy_pep_xgb = accuracy_score(y_test_pep, best_xgb_model.predict(X_test_pep))
baseline_preds_pep = np.full_like(y_test_pep, fill_value=majority_class_pep)
baseline_accuracy_pep = accuracy_score(y_test_pep, baseline_preds_pep)

print(f"Best Parameters: {best_params}")
print(f"Tuned Model Accuracy: {accuracy_pep_xgb:.4f}")
print(f"Baseline Accuracy: {baseline_accuracy_pep:.4f}")

with mlflow.start_run(run_name="XGB_PEP_Tuned_Model"):
    # Log best hyperparameters
    mlflow.log_params(best_params)

    # Log accuracy metrics
    mlflow.log_metric("accuracy", accuracy_pep_xgb)
    mlflow.log_metric("baseline_accuracy", baseline_accuracy_pep)

    # Log classification report as an artifact
    report_pep = classification_report(y_test_pep, best_xgb_model.predict(X_test_pep))
    report_path = "classification_report_pep_tuned.txt"
    with open(report_path, "w") as f:
        f.write(report_pep)
    mlflow.log_artifact(report_path)

    # Infer the model signature
    signature = infer_signature(X_train_pep, y_train_pep)

    # Prepare an input example by resetting the index
    input_example = X_train_pep.iloc[:1].reset_index(drop=True)

    # Log the model with signature and input example
    mlflow.sklearn.log_model(
        sk_model=best_xgb_model,
        artifact_path="XGB_PEP_Tuned_Model",
        signature=signature,
        input_example=input_example
    )

    # Save the trained model to a pickle file
    pickle_filename = "xgb_pep_tuned_model.pkl"
    with open(pickle_filename, "wb") as file:
        pickle.dump(best_xgb_model, file)
    mlflow.log_artifact(pickle_filename)
    print(f"Tuned model saved as '{pickle_filename}' and logged with MLflow.")
# Out:
# 2025/04/21 17:54:13 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '13f55a2bb65b4663b15e20e384bbf454', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# 2025/04/21 17:54:18 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f49404ad665f4a14a03fb267e24dfce9', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:54:23 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '5dc96c684019448792bd3e248fb5ef5a', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:54:28 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f62feb60ca1e4aa290e8a57ca621e234', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:54:33 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b9ca38a278134a4d9b5a198b5a091e3f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:54:38 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1e3024591dd249c8830cf2ded0dc3b55', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:54:42 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '2141e9014a2e4125b5b81cc78ba0ef5f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:54:47 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ac945ce785c04462bff8ae054268540e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:54:52 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c6f9ae7effbe4cd6a2b1819b218d5f2e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:54:57 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c2ce10b379964d8f9028ec01a1b6cde7', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:55:03 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '8a13128f9ba94ee187520e77a9fbc852', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:55:07 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '9fc05cec6418453ea45399c88d8706eb', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:55:12 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'e787f40ec361485e8c8a4be42167bfe4', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:55:17 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'e8ff4c66ab024efd9b9dc49e923ed6c0', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:55:22 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '97bf447da7ec431d8cd613cd2795243f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:55:28 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '7d1b7c7c16c0465289a42e2feaad7c8c', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:55:33 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0bcbeb75f61644498f81699b57d19cc0', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:55:37 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b6d2679f54904f4ebea2d15070b02afa', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:55:43 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '2581c5c8bc024da2ab87c30180b26478', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:55:48 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'd3ec3fe910f949a8bdac6f4154319caa', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:55:53 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'd3ad83f3327642a8b3d407c41d6bcadb', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:55:58 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '9c533c08799648438ad1078c19fd45ff', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:56:04 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '2b0e55c1e87c44228fa306ffcf508bb0', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:56:10 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '4cfcd36b758841cb8c2af31504d7b9b5', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:56:14 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'dd203e44fbab4821a35f9e6b9817acf7', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:56:20 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'de9747a07ddd4e68930e2164194894a7', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:56:25 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '39d4b072c1d740aeaa8a82757743b3e9', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:56:30 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '5b79fada300c4f5394c917928fffb310', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:56:35 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1a404ef5ba13433b994e77a88a4df3b6', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:56:40 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '976100555f9f4739ac1b4fac9e02e547', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:56:46 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3da5c21499d142599ba4e247853097e6', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:56:51 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'cf512b036bd540fabd5ad5f4bcf01651', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:56:56 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f4f06732bd5040fb819504cea5356eb0', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:57:01 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '9cdd362a5dc44d0d910bb4905d933d3c', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:57:06 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '47a1293ad02f4875bcd64a0366733e65', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:57:12 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'fc6579c05ddd4b138090a8a06561499e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:57:17 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '529af118f0ed444fa4c75101b2083b24', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:57:23 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '4537ba65c4024d94b6b5cdb6bc93b039', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:57:27 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '8d899ee9cc5c45389a6a048ec32f751f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:57:33 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '31da70ef330c4f689ee5b29974ccefd0', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:57:38 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3057165a4512418dbf014ed5bd336f7f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:57:43 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '4b40966f2cf3482891eab40180bf163e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:57:48 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '33b42748368746d397e339460128ab0d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:57:53 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '928737a42db04623a54159afda5800d4', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:57:59 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'cd8aedaa9546406385747a22b0c45c44', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:58:03 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '59f5d595a6b345cc99ef21b7d1f32987', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:58:08 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'a3872cdfb4db4b3d875e28fc2db3dd6e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:58:14 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '600ffa941eb04075ab3a8d249213608d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:58:19 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3c770e3ba73b4624b6c8254c2809ebf5', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:58:25 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3bb7c562804a49538158ed9bb2f0b826', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:58:30 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0c6a55625ed840a29c7458e083033395', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:58:36 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0e51963eb157447a9aa5c1ccde72d12c', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:58:41 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '438d71e651404c9aa3c5eea913af008f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:58:46 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'fa6540de4829402d869a1a30e4383b32', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:58:52 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'faeb4f68dfbb49d1b66b242c6afd194d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:58:56 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '51ca2c571716429782a32a6b397ae258', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:59:02 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b03fa84ac407430ebcb9e8f8fc82fc31', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:59:07 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '2c504f09c4a4430f95bb98e69bf49d32', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:59:12 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '401ce8920c9541c1996901372c4212a3', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:59:17 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ace54cb51dcc454a979e57df21dbc479', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:59:22 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'eb7742e76522464ca4abfbc1714edac4', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:59:27 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c2488e21ebe44091bd405d3ff922cd2f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:59:32 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '983742a3da5840cb910e589315e56737', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:59:37 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '01c00f16fef342dc83f9692be644efb0', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:59:43 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '541490aee2494affb9a8b7063615e1c8', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:59:47 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '98ef454e07ab4559ab4e0e295c808be6', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:59:52 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'd15a528f27e84f0091bf2f78bc9f517f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 17:59:58 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'e3a996ef59924845a0a9969e4da4a49e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:00:02 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c9151fd4a7e2488792c9843315042dd0', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:00:08 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '066821eebe17405daabbc001bd81a75d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:00:13 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '6ac4048a0a234dedb631f07e179e072d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:00:18 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '137b00e0dbd14407b44c1c415154c515', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:00:23 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '44f393824e89480a9c74546bf9e31cb1', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:00:28 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'cc49cdeb81c54594aed00ee3fc0274b0', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:00:33 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '45bf4a1ab00549dc83907ebf53d545ac', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:00:38 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '01af11617a30482aab2e0610e2be8db4', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:00:43 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'a74d832f2f674d6fb62a6b4032f61727', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:00:50 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '4b56227658f540838a6a741cc458a5d3', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:00:57 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '82cc0b3756424c33884979757dd30dd9', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:01:02 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b0eb969448c7420db7cc9eb1dba1324c', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:01:08 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1bb3df0cbb314beb975a6f1e858f0d58', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:01:14 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b64b6cf05bfb4f139aa852d94f7c213e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:01:19 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3aabefc0135d4cf3bc63504a2c086420', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:01:25 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '9c4761ac0931456191d90cc1deb03707', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:01:30 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ed41c89f044e433ca6b85f9c424f076d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:01:36 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '151e6aa13ca1423da7323832e1fdd322', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:01:42 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'df10cf87723942a7a2165846adf9fe19', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:01:48 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '9f4d0eee1df141dfb70eb8aa3d07c45c', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:01:53 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '7f45e0d00c03416097019576a424839b', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:01:58 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b1d604a4187142dc8f5935e63e4a191e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:02:05 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'cabe070e24ad45bbbd154e630eaef1a6', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:02:10 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ceb20f20b65d488ea6bd56597b25161e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:02:15 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1da4a0a1ae4e413398f33f5ca94f4170', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:02:20 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '6c64086bfa704f6d8ad30aa80a3760f2', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:02:26 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '98a6dc7c04fc4e759b8197ffd45d007d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:02:31 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'bd5944a2b1524a0296b637e0231a939f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:02:36 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '76deaa7a77c24800a491ed8083c4d4dd', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:02:43 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b48da4f70d3445d885c1b1e031940f30', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:02:48 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '92dd461b88c9453cb940971e3cda5aa5', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:02:54 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '2a916ba4b2604f2cb9ff1a389ff65c82', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:02:59 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '9b18dfe34ec848c7b6fb26a13c42c6e7', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:03:05 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '6af76e5723344824a5f08e3ddd295e9a', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:03:10 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1e5b0e1f01b94bd6b5efdc33511edfc6', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:03:16 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '644d605380094515bb05708ed5df50fd', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:03:22 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '9172d03882e244d3aed0bb018b5616a9', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:03:28 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '38854c8f8d5c458ea77b21a7e7b58c55', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:03:33 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0cf36772c5124f759ba7eca2dc762768', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:03:38 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '6f2268ea85fc4582a8bad82f245fb542', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:03:45 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'a23bdf4acb2a461395bc2281ef1ce78b', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:03:50 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'fe6039d680654c81a2d683c23c2c873e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:03:56 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3d6324baf7e644a68cbce71613340194', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:04:01 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f2810b6215c44212ad507e714388ad6f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:04:06 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '172fae4ab85f4c18823f0ebb9fb1e3ce', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:04:11 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c7502c18cae3401589b9d8332ae2966c', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:04:16 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'bcafe689908a46a882bcb3aa0fd9d95b', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:04:21 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '2d74febcc81d425491048bc8aa013225', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:04:26 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '663ad7290e724644b5bf29f1f3857c3c', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:04:32 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ab9fdfeac73f477da0740871c89480cb', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:04:36 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'e1b4e27a723b4fcca20066aa62f16565', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:04:41 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b7943ca946144f5db50bc66f053ac58a', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:04:47 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '04328d0a698c40a49c60647bd6498062', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:04:52 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f1aab4f835bc46188993155598eb14ab', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:04:57 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'd7d272f38ff9472980f695d5b9945e8a', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:05:02 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c6aa71f4e04442e9b38defd5452fd8e2', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:05:07 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c1c43c1da2364c678aa8a98846188b29', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:05:13 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'aac5424b52744e5c980640098971cba1', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:05:18 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '93e49cbe962841fdb8cc27537525485e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:05:23 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '81ded5e94575403f947230304abc5f40', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:05:28 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f2300d2aa0a34756aade650b4f96006d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:05:33 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '7360d71797fc414cb78d41d06e0b66ab', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:05:38 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ad539deaa59241c3be1762a1585da821', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:05:43 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1c32acec784547f3a5eae88c3963c328', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:05:49 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'a4a271ac18d841aeab162e56c4012004', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:05:54 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'bfe3726c77d743d7a60d8a542f38faca', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:05:59 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'cc25f8dbc0d44769bdb4c7177c112199', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:06:04 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '58ef4e7333784bcf8464ea391acab04d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:06:09 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '4b571c2c4db24053a771ae60c2fa9966', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:06:14 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '59b6638d28674c3ea846916548f20ec0', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:06:19 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '857b5a37021d4a72892f0b690304f383', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:06:25 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0c2d876d22954e64bf60d3a0a8f5758d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:06:29 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '79a7d1d940284b7d95b990a1e48dff27', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:06:34 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '43da798b27fb420aa11d6205d3280609', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:06:40 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '05f7f1166aad420b86f474aa0f81fff3', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:06:45 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '836e55c0e1ae4a7a93cca4cdcb572532', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:06:51 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '7875ea130762429b853eee595810e938', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:06:56 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b08e38e1b10e47e081125bf66efc7c9b', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:07:01 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '518ca7bd44464a95a0566082efcffe4e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:07:06 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '8fb2ba9fabef4476a5c19b6de10cde32', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:07:11 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '444a5b2625da4bf997ae620a9ce40ed7', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:07:17 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '990be61eea68452b8800fbda07d8f48c', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:07:21 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c6a373a40b394a409327040c16e3129f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:07:27 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '20b883e2155d41f4b0e98ad5e23a7df8', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:07:32 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ce79406d171b4a588822d860f82781ec', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:07:36 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '14ba9bd9dbae42349920e77871d3b323', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:07:42 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '9d3ac05b69124810bbe44d7e587c9ea4', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:07:48 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'd8fce852799541099cd194dadae42c88', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:07:53 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '793161f1b2f944f9af73a9950ace2ac8', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:07:58 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c480f91c2308496dabd43c9fd87bf782', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:08:04 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '09376d6e2d45441aa82f96a2462a21b8', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:08:09 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '759204ac85314e35802d66e0bf147588', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:08:14 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ac2fdbebbc8d4b0384a58d2196724baf', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:08:20 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'e62f75d8522c42fea12b6196e0b4864b', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:08:25 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0f407bd16ca945ca826d3149f5be14fe', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# Best Parameters: {'learning_rate': 0.2, 'max_depth': 7, 'n_estimators': 150, 'subsample': 1.0}
# Tuned Model Accuracy: 0.7958
# Baseline Accuracy: 0.5236
# Tuned model saved as 'xgb_pep_tuned_model.pkl' and logged with MLflow.

# %%
# --- Extract Feature Importance and Plot ---
# Ensure feature importance is extracted
feature_importance = best_xgb_model.feature_importances_

# Get feature names if using a Pandas DataFrame
if isinstance(X_train_pep, pd.DataFrame):
    feature_names = X_train_pep.columns
else:
    feature_names = [f"Feature {i}" for i in range(len(feature_importance))]

# Combine feature names with importances
importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Importance": feature_importance
})

# Sort features by importance in descending order
importance_df = importance_df.sort_values(by="Importance", ascending=False)

# Plot the feature importance
plt.figure(figsize=(10, 6))
plt.barh(importance_df["Feature"], importance_df["Importance"], color="skyblue")
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("Feature Importance for PEP XGBoost Model")
plt.gca().invert_yaxis()  # Invert y-axis to show the highest importance at the top
plt.tight_layout()
plt.show()

# Save feature importance as a CSV for further analysis
importance_df.to_csv("feature_importance_pep.csv", index=False)
print("Feature importance saved to 'feature_importance_pep.csv'")
# Out:
# Feature importance saved to 'feature_importance_pep.csv'

# %%
# --- Helper to flatten MultiIndex columns if necessary ---
def flatten_columns(df):
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = df.columns.get_level_values(0)
    return df

# Ensure training and testing sets have a flat column index
X_train_ko = flatten_columns(X_train_ko)
X_test_ko = flatten_columns(X_test_ko)

# --- Hyperparameter Tuning ---
# Define parameter grid for GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.8, 1.0]
}

# Initialize the base XGBoost model
base_xgb_model = XGBClassifier()

# Perform grid search with cross-validation
grid_search = GridSearchCV(
    estimator=base_xgb_model,
    param_grid=param_grid,
    scoring='accuracy',
    cv=3,  # 3-fold cross-validation
    verbose=1
)
grid_search.fit(X_train_ko, y_train_ko)
best_xgb_model = grid_search.best_estimator_

# Log the best configuration separately
best_params = grid_search.best_params_
accuracy_ko_xgb = accuracy_score(y_test_ko, best_xgb_model.predict(X_test_ko))
baseline_preds_ko = np.full_like(y_test_ko, fill_value=majority_class_ko)
baseline_accuracy_ko = accuracy_score(y_test_ko, baseline_preds_ko)

print(f"Best Parameters: {best_params}")
print(f"Tuned Model Accuracy: {accuracy_ko_xgb:.4f}")
print(f"Baseline Accuracy: {baseline_accuracy_ko:.4f}")

with mlflow.start_run(run_name="XGB_KO_Tuned_Model"):
    # Log best hyperparameters
    mlflow.log_params(best_params)

    # Log accuracy metrics
    mlflow.log_metric("accuracy", accuracy_ko_xgb)
    mlflow.log_metric("baseline_accuracy", baseline_accuracy_ko)

    # Log classification report as an artifact
    report_ko = classification_report(y_test_ko, best_xgb_model.predict(X_test_ko))
    report_path = "classification_report_ko_tuned.txt"
    with open(report_path, "w") as f:
        f.write(report_ko)
    mlflow.log_artifact(report_path)

    # Infer the model signature
    signature = infer_signature(X_train_ko, y_train_ko)

    # Prepare an input example by resetting the index
    input_example = X_train_ko.iloc[:1].reset_index(drop=True)

    # Log the model with signature and input example
    mlflow.sklearn.log_model(
        sk_model=best_xgb_model,
        artifact_path="XGB_KO_Tuned_Model",
        signature=signature,
        input_example=input_example
    )

    # Save the trained model to a pickle file
    pickle_filename = "xgb_ko_tuned_model.pkl"
    with open(pickle_filename, "wb") as file:
        pickle.dump(best_xgb_model, file)
    mlflow.log_artifact(pickle_filename)
    print(f"Tuned model saved as '{pickle_filename}' and logged with MLflow.")
# Out:
# 2025/04/21 18:08:35 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ad5b647fd1114b069993cca940e6ae76', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# 2025/04/21 18:08:40 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '4f51e257f2e3415182444b502541f3ae', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:08:46 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '79e300af8b7f4a06bd7866a4138fabdf', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:08:50 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c4c9c29c3ab6453a8547308bdf58a618', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:08:56 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'fbeae574e14c422f9881b10e489e8891', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:09:00 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '9ed49a8f211f46998f838403617d1058', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:09:05 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f2515d761f8d4e66a9ace2a049b79be4', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:09:11 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3a0b42e1c1d94e02965b9b8149d70a88', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:09:16 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'bc8a16623c324948a4709a384fb093ae', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:09:21 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '113c7f06e009446aa7a7559b8d97cbe4', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:09:26 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '36503b8ddf7647838ba9427a5a3af2b8', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:09:31 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f21dbdc10b094e8c8daadb00c3bc22ff', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:09:36 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'efff13e8a8de47f9ab59cf636a667951', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:09:41 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '4eef422b9c304d48af88d9ec76673208', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:09:47 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '99957ebc48634eceabd2e6e3c6884f69', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:09:52 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '62c7f23c36bf4c469ec8c91d64ddca53', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:09:57 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3ae988d5de2c49a1807af457f18ab8bb', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:10:02 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'eb7aea3351cf4693bde862fc3e58b1d7', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:10:07 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '8c76ea321eba41f8966cc8d83423d0be', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:10:12 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '71c0efcb1fe94258a87107509a34dae6', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:10:17 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '5b9896e2e0034e0d8f62571a37ba3aaa', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:10:22 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'aef997544bff4109b6765ce54a43f93c', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:10:27 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '5f4960bf40b648f6844434fb91f9bc08', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:10:32 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '05b2d2fe3a3345b7a9bf1684ce5ee3ae', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:10:37 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '177c531c1af541ba8bd9202f505d915e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:10:42 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c8620047968644a5aeb39a4f5ae50510', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:10:48 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'a9480c540b6e4b94bcae0a5e735ec74f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:10:53 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '4d7a733267ed4b568c23473ff5ccdc92', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:11:00 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'e918c600d05249c58501d624b2ec702b', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:11:06 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '88d6ecf6972a4435b67a505a155c1653', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:11:12 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1fa0a775e7e04d1a9da50e8512d7a875', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:11:17 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '9b235520c43c43a9b66909403235ee1f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:11:22 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '45c1f00d0cd24a889f90b12bb1b0a47e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:11:28 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ae04f2d5cc414c45a97ab5bcb8ee5896', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:11:33 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '4a002775b541465fbf10bc03fec3a9b9', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:11:38 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b2efb618aa6a4d99afebf663c5a2cc27', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:11:43 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b67b211f480144cf804f80128a850a99', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:11:49 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'cb6426ede60c44b49b1d02bd9ebd78d2', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:11:54 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '8eb135780b7a4bcf8ee757f6f628a503', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:11:59 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'eaeaf99c71284fb1b01d89d0b6121661', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:12:04 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '7674a41a73524efd9e1b800591b9a8ac', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:12:09 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '043ec07880ba436da58cfc21a6ef6459', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:12:14 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '959278e37abb43bcaa76c98211a80675', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:12:19 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1704fbd1ab2e45079be2a971a7767048', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:12:25 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '80ca693b4c2641798bdfa47e0d716a1d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:12:31 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '8506899b688f4275b4e52cbd3d93a173', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:12:36 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b2c82b5e286744219756a79b2c3dcb7c', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:12:41 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '06f3cab4043e46f09003bda675419a76', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:12:46 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '4839caa06a6148eaadd8ef7f8e753d3d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:12:52 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '15c493a02aaa401d9a9fb90460000bb1', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:12:57 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '8fb25676dce74e76a95243c23dd6af18', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:13:03 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0a0a4dbb9f724d8c89be2e6d4acc76bf', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:13:09 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'bd4b8f717e7041d59e8124f0b01c398c', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:13:14 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'd66149ef35734e2e9f3a6e61271fca0d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:13:20 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '417ca4316b2748b7add8a347d9c515bc', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:13:25 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f4bbe644a7024d16a1926bcff19b7218', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:13:30 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '11436005d7f94be48a2c7336b81cf023', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:13:35 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ecbdffd5b2314e428203c7f1c7cd4106', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:13:40 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '15fcfb52fca34094ba0bc52b77c85c25', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:13:45 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'd09d804ca1674bb1af8c63a2e23fb014', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:13:51 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'cbdfbefe980e4da59540e4a7e707ba56', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:13:57 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '51dafcdff50b4a77af3efb6a28a9ea98', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:14:02 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f8d6b0206f8049c28fb5810d3b763f7e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:14:07 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '407820061f4441548cede2fcca89e6ca', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:14:12 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'fdc1c38397a14a92bcbcaa9d86663513', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:14:17 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ab557151c47341cc93369c314bd38c90', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:14:22 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'e268509d70724b72845bf20e296c1ee3', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:14:27 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '2aef9b3eaae04f0d92bb3edaf49b0577', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:14:33 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b03217e5db9f497fb16f7ec48b2e8c2b', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:14:37 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1e7132b6d0ad4493b06f6ce38b59ac04', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:14:43 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f08cb112673747c1b96d1b56deb96ea8', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:14:48 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '46c1c31062214e0cadc7835d00fb634f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:14:53 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '2166c3979531445bb327b15512f02ea0', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:14:58 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '5cfb021b7d154daa923c0d6fd9dd23d7', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:15:03 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0e4096eaa2954e068a8a0c4c5ac73240', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:15:08 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '991886b933c34972886abf21d495f384', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:15:13 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '01ed4240c8f2488295d6b41a3bc65cf0', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:15:18 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'bcf7547f12ad4cb28d1f89ba86fc9ba7', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:15:23 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f88101eb553947fdadac6da48788d15a', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:15:28 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '10d802bd9e9c434495ba81914069f0dc', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:15:34 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '6c7fb88e84d0411a9e74b656a4463d53', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:15:38 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '226f1da0a43a40b19a011651f8e528f6', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:15:44 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '30309848077544678c41dbe3a5abb732', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:15:49 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0d466de41e9b488c8d6616c9f27a3acf', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:15:54 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '19b38c2ef29f4b70a756023adc8fd403', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:16:00 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '413f5d464b744b2299d3cf5057e1a355', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:16:05 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '9a52a89c71224422ab051524dd18db3c', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:16:10 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3788ee8d2bc34c47a31ea892416ecaff', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:16:15 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'bf1a8d8676824c7f998e601916cb9fcd', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:16:20 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '137d8d1f8c33415f84396c83261513ab', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:16:26 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'e34bca01d499474e940f899b935c2f36', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:16:31 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '36273a276a6e4c0eb95ca90ba35e6e3d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:16:36 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'bce9ea50d1d54ce4a4ac5bd3f6bb4e37', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:16:41 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '65295eff347b49419d1f3fe77773913d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:16:47 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f149776893c94ecebc944a43dd925d8f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:16:51 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'e0e77ace945f4919b4e5d62ab4a7f219', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:16:56 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '68968a28a7dd46c8b6408b16c4a1976c', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:17:02 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c1b1b71fd6884c89ac1b6fd4237c7e01', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:17:07 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'e8765f33d5264ebbaf688968ce58591e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:17:12 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'fd3d6f3e64e641a0a58a532c38269aae', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:17:17 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b4b9eb735fc24182a4e2efeb2874b055', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:17:23 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'a903e41baa4f4d10a31e3c95adbecbf5', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:17:28 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '5b0c653e7b4a44a990a0eef8b5952251', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:17:33 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b8c0d5f5b4884333a89eadcf6d6ed65f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:17:39 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '466aba9cd54348d6a852d56a889d7658', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:17:44 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '655d46d8fc3c42a08b2998624133b149', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:17:50 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'dddb057d96b64db3b3a7bc437e3fe212', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:17:55 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0d05bbe5c46d4e6caea05e40e846ae14', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:18:01 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '435e7bad518048f5b2c1f9abb20998bf', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:18:05 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '35a224bca9384307996cf001f881eb66', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:18:10 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f74e67e8984149a69eb13dbc7a70158e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:18:16 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0770025401554fd49cb1e752b5992e9f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:18:21 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '56771edce57845e3b49fa256d31d34ff', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:18:26 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '36bcd589f95040d98630e78592aa6880', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:18:31 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'df8a161281264c3488eb9b199bb98d4a', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:18:36 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f0f490bc95da4a3584d2906406e48893', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:18:41 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '5a1bb9165d9e47e7bfff0b88adf1dbab', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:18:46 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'aaec72decd8f464b9155c1f24bb31843', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:18:52 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'd76f2180ee944c4fbe474161c60367a8', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:18:56 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '2ed4feef740d427da8ff40735325d344', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:19:02 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '264ef20b6c5f4d0eabc0014ef1854e1f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:19:07 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '93c63719f1d7440585fbd39b45578fdd', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:19:11 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '66b52dd3570b41e8b18066ed95d863d5', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:19:17 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '14f2bb13f6f24593b04ad61f72f30b42', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:19:22 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c3f980306c1343aabd4f3bf1b1e37cf2', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:19:27 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '913b6153f0a3409a92aad5d66f471290', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:19:32 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '79f21534c7c043c9817f9de173fbed7b', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:19:37 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '866e1863434c48c8918b69d706828002', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:19:42 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0e873102a64548cf90c409ccc6133491', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:19:47 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '8eabad4f0f3e432a8aa41dd92d7c45f6', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:19:52 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'e42e8b8bdf354e6f8d0b1186542bc2d5', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:19:57 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '921e9e3b8d944d46a8fabc6178705965', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:20:02 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '9a0e64431ac14e1b97344fb5b6d17acb', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:20:08 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ed97d4822c4c41ec944b30aa20ba8595', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:20:13 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '55c948e147ef454dbabcefba9f2ca016', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:20:19 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '8726ee86cc7f4b8eaed017c943a4a6fb', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:20:23 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c1359bd7a4b84b1c89d31c27b8d4c8ee', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:20:29 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '875fdaf5c038436f8d0df2703e04fc05', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:20:34 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1a2fdc2b722748cf83602ecb8051422a', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:20:39 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '258ab4eb389641e8ba7677a6c95f95c6', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:20:45 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '8d0202ad1f4b4b0bb61a3b8d7e0fb56c', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:20:50 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c379bd3264354ed78e856019de1a68e3', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:20:55 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ca8ce6c7600d4c4ea9022427c8ac59de', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:21:00 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1db65a66353141f1ae00d9c1ab128109', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:21:07 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '19f94737cb614fef9edfeb0906129fad', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:21:14 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'da05ad9b86464dd0aaf8c4120e5591b7', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:21:20 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'db8bbf53056644aeae5cab777675b51d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:21:25 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '2e7f5d4308b44ea98fcbf6b4bc1759f9', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:21:30 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0cabc917235e431ba049e518132e8985', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:21:35 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '7a3bea5e4d3d4809a8017ad8998bd243', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:21:40 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f048c6a0cd2e45ed83a4a80825e3f34a', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:21:46 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0136cee3cb344ecab66947bfb31ea641', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:21:51 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ba388726d30c4e69997f8bb52ae20a33', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:21:57 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b8b673b3c98141d39d8d6019d83bc771', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:22:02 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '2530234f791443bb807622a4d99de016', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:22:07 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'fe7d6ff740e64196a0b2125c90bf1aac', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:22:13 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'd93ef585b40c4b9a8fe960f3c842f843', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:22:19 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '92064745459c482cbf5148885bd0c982', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:22:25 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '7b5bbd116123426f942bfbcda8830480', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:22:30 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3623fb316616456cb76d5321aaca5124', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:22:35 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b189df615b3b497a843d54e4ce74fe44', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:22:40 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'd680984087f94c778b113e6496813ce2', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2025/04/21 18:22:46 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'a4506872cb5f41c497a9cc5b080ad185', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# Best Parameters: {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 150, 'subsample': 1.0}
# Tuned Model Accuracy: 0.7016
# Baseline Accuracy: 0.5393
# Tuned model saved as 'xgb_ko_tuned_model.pkl' and logged with MLflow.

# %%
# --- Extract Feature Importance and Plot for KO Dataset ---
# Ensure feature importance is extracted
feature_importance = best_xgb_model.feature_importances_

# Get feature names if using a Pandas DataFrame
if isinstance(X_train_ko, pd.DataFrame):
    feature_names = X_train_ko.columns
else:
    feature_names = [f"Feature {i}" for i in range(len(feature_importance))]

# Combine feature names with importances
importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Importance": feature_importance
})

# Sort features by importance in descending order
importance_df = importance_df.sort_values(by="Importance", ascending=False)

# Plot the feature importance
plt.figure(figsize=(10, 6))
plt.barh(importance_df["Feature"], importance_df["Importance"], color="skyblue")
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("Feature Importance for KO XGBoost Model")
plt.gca().invert_yaxis()  # Invert y-axis to show the highest importance at the top
plt.tight_layout()
plt.show()

# Save feature importance as a CSV for further analysis
importance_df.to_csv("feature_importance_ko.csv", index=False)
print("Feature importance saved to 'feature_importance_ko.csv'")
# Out:
# Feature importance saved to 'feature_importance_ko.csv'

# %% [markdown]
#  ### Fine-Tuning LSTM
#  Experiment with different neuron counts, dropout rates, and sequence lengths.

# %%
# --- Callback Definitions ---
early_stopping_pep = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint_pep = ModelCheckpoint('best_model_pep.keras', save_best_only=True, verbose=1)

# --- Define Model-Building Function for Hyperparameter Tuning ---
def build_lstm_model(hp):
    model = Sequential()
    # First LSTM layer with variable units
    model.add(
        LSTM(
            units=hp.Int('units_1', min_value=32, max_value=128, step=32),
            return_sequences=True,
            input_shape=(X_train_pep_lstm.shape[1], 1)
        )
    )
    model.add(Dropout(rate=hp.Float('dropout_1', min_value=0.2, max_value=0.5, step=0.1)))

    # Second LSTM layer
    model.add(
        LSTM(
            units=hp.Int('units_2', min_value=32, max_value=128, step=32),
            return_sequences=False
        )
    )
    model.add(Dropout(rate=hp.Float('dropout_2', min_value=0.2, max_value=0.5, step=0.1)))

    # Dense layers
    model.add(Dense(units=25, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))  # Output layer for binary classification

    # Compile the model
    model.compile(
        optimizer=hp.Choice('optimizer', values=['adam', 'rmsprop']),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

# --- Hyperparameter Tuning with Keras Tuner ---
# Add batch size as a tunable parameter in the tuner itself
tuner = kt.Hyperband(
    build_lstm_model,
    objective='val_accuracy',
    max_epochs=20,
    factor=3,
    directory='keras_tuner_dir',
    project_name='PEP_LSTM_Tuning',
    overwrite=True  # To allow rerunning without errors
)

# Run hyperparameter search
tuner.search(
    X_train_pep_lstm,
    y_train_pep,
    validation_split=0.2,
    callbacks=[early_stopping_pep],
    verbose=1,
    batch_size=32  # Default batch size for the tuner search
)

# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Get the best batch size explicitly
best_batch_size = best_hps.get('batch_size') if 'batch_size' in best_hps.values else 32

# Retrieve the best model
best_model = tuner.get_best_models(num_models=1)[0]

# Train the best model on the entire training data
history = best_model.fit(
    X_train_pep_lstm,
    y_train_pep,
    epochs=20,
    batch_size=best_batch_size,
    validation_split=0.2,
    callbacks=[early_stopping_pep, checkpoint_pep]
)

# --- Evaluate the Tuned Model ---
lstm_predictions_prob_pep = best_model.predict(X_test_pep_lstm)
lstm_predictions_pep = (lstm_predictions_prob_pep > 0.5).astype(int).flatten()

accuracy_pep = accuracy_score(y_test_pep, lstm_predictions_pep)
print(f"Accuracy: {accuracy_pep:.2f}")
print(classification_report(y_test_pep, lstm_predictions_pep))
# Out:
# Trial 30 Complete [00h 00m 31s]
# val_accuracy: 0.5098039507865906
#
# Best val_accuracy So Far: 0.529411792755127
# Total elapsed time: 00h 12m 35s
# 2025/04/21 18:35:34 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '4a40e0565f3d4048a6078ff81771b7da', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current tensorflow workflow
# 2025/04/21 18:35:34 WARNING mlflow.tensorflow: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Epoch 1/20
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4834 - loss: 0.6943
# Epoch 1: val_loss improved from inf to 0.69352, saving model to best_model_pep.keras
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.4856 - loss: 0.6942 - val_accuracy: 0.5098 - val_loss: 0.6935
# Epoch 2/20
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5322 - loss: 0.6913
# Epoch 2: val_loss improved from 0.69352 to 0.69342, saving model to best_model_pep.keras
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5308 - loss: 0.6915 - val_accuracy: 0.5098 - val_loss: 0.6934
# Epoch 3/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5516 - loss: 0.6899
# Epoch 3: val_loss improved from 0.69342 to 0.69338, saving model to best_model_pep.keras
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5491 - loss: 0.6903 - val_accuracy: 0.5098 - val_loss: 0.6934
# Epoch 4/20
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4573 - loss: 0.6945
# Epoch 4: val_loss improved from 0.69338 to 0.69302, saving model to best_model_pep.keras
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4604 - loss: 0.6944 - val_accuracy: 0.5098 - val_loss: 0.6930
# Epoch 5/20
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5226 - loss: 0.6918
# Epoch 5: val_loss did not improve from 0.69302
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5220 - loss: 0.6919 - val_accuracy: 0.5098 - val_loss: 0.6933
# Epoch 6/20
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5217 - loss: 0.6923
# Epoch 6: val_loss did not improve from 0.69302
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5223 - loss: 0.6923 - val_accuracy: 0.5098 - val_loss: 0.6938
# Epoch 7/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5291 - loss: 0.6895
# Epoch 7: val_loss did not improve from 0.69302
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.5287 - loss: 0.6895 - val_accuracy: 0.5098 - val_loss: 0.6935
# Epoch 8/20
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5707 - loss: 0.6864
# Epoch 8: val_loss improved from 0.69302 to 0.69297, saving model to best_model_pep.keras
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5642 - loss: 0.6870 - val_accuracy: 0.4967 - val_loss: 0.6930
# Epoch 9/20
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5623 - loss: 0.6891
# Epoch 9: val_loss improved from 0.69297 to 0.69249, saving model to best_model_pep.keras
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5575 - loss: 0.6895 - val_accuracy: 0.4771 - val_loss: 0.6925
# Epoch 10/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5220 - loss: 0.6902
# Epoch 10: val_loss did not improve from 0.69249
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5231 - loss: 0.6902 - val_accuracy: 0.5098 - val_loss: 0.6927
# Epoch 11/20
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5334 - loss: 0.6882
# Epoch 11: val_loss improved from 0.69249 to 0.69191, saving model to best_model_pep.keras
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5321 - loss: 0.6888 - val_accuracy: 0.4641 - val_loss: 0.6919
# Epoch 12/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4986 - loss: 0.6934
# Epoch 12: val_loss did not improve from 0.69191
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.4986 - loss: 0.6934 - val_accuracy: 0.5098 - val_loss: 0.6930
# Epoch 13/20
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5147 - loss: 0.6925
# Epoch 13: val_loss did not improve from 0.69191
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.5134 - loss: 0.6926 - val_accuracy: 0.4641 - val_loss: 0.6930
# Epoch 14/20
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5400 - loss: 0.6910
# Epoch 14: val_loss did not improve from 0.69191
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.5376 - loss: 0.6910 - val_accuracy: 0.5033 - val_loss: 0.6928
# Epoch 15/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5107 - loss: 0.6929
# Epoch 15: val_loss did not improve from 0.69191
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.5121 - loss: 0.6929 - val_accuracy: 0.5098 - val_loss: 0.6926
# Epoch 16/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5322 - loss: 0.6910
# Epoch 16: val_loss did not improve from 0.69191
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5322 - loss: 0.6910 - val_accuracy: 0.5098 - val_loss: 0.6925
# Epoch 17/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5541 - loss: 0.6902
# Epoch 17: val_loss did not improve from 0.69191
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5527 - loss: 0.6903 - val_accuracy: 0.5033 - val_loss: 0.6933
# Epoch 18/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5149 - loss: 0.6933
# Epoch 18: val_loss did not improve from 0.69191
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5153 - loss: 0.6932 - val_accuracy: 0.5033 - val_loss: 0.6932
# Epoch 19/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5393 - loss: 0.6910
# Epoch 19: val_loss did not improve from 0.69191
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5392 - loss: 0.6910 - val_accuracy: 0.4902 - val_loss: 0.6932
# Epoch 20/20
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5342 - loss: 0.6883
# Epoch 20: val_loss did not improve from 0.69191
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5332 - loss: 0.6884 - val_accuracy: 0.4641 - val_loss: 0.6940
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# Accuracy: 0.55
#               precision    recall  f1-score   support
#
#            0       0.53      0.69      0.60        91
#            1       0.61      0.43      0.50       100
#
#     accuracy                           0.55       191
#    macro avg       0.57      0.56      0.55       191
# weighted avg       0.57      0.55      0.55       191

# %%
# --- Save Evaluation Metrics ---
evaluation_metrics_pep = {
    "accuracy": accuracy_pep,
    "precision": classification_report(y_test_pep, lstm_predictions_pep, output_dict=True)["weighted avg"]["precision"],
    "recall": classification_report(y_test_pep, lstm_predictions_pep, output_dict=True)["weighted avg"]["recall"],
    "f1_score": classification_report(y_test_pep, lstm_predictions_pep, output_dict=True)["weighted avg"]["f1-score"]
}

metrics_path = "evaluation_metrics_pep.txt"
with open(metrics_path, "w") as f:
    for metric, value in evaluation_metrics_pep.items():
        f.write(f"{metric.capitalize()}: {value:.2f}\n")
print(f"Metrics saved to {metrics_path}")

# --- Save the Tuned Model in Pickle Format ---
with open("lstm_model_pep_tuned.pkl", "wb") as file_pep:
    pickle.dump(best_model.get_config(), file_pep)  # Save the model configuration
    pickle.dump(best_model.get_weights(), file_pep)  # Save the model weights

print("PEP LSTM model saved as 'lstm_model_pep_tuned.pkl'.")

# %%
# --- Prepare SHAP Explainer ---
# Wrap the input data using shap.maskers.Independent (specific for TensorFlow models)

# Initialize explainer with X_train_pep to have a compatible data shape
masker = shap.maskers.Independent(X_train_pep)

# Create SHAP explainer for the LSTM model
explainer = shap.Explainer(best_model, masker)

# Calculate SHAP values for the test set
# Pass X_test_pep_norm (2D) to the explainer since it's compatible with the masker's expected shape
shap_values = explainer(X_test_pep_norm)

# --- Aggregate Feature Importance ---
# SHAP values provide importance for each sample. Aggregate across all samples for global importance.
feature_importance = np.abs(shap_values.values).mean(axis=0).flatten()

# Get feature names if using a Pandas DataFrame
if isinstance(X_train_pep, pd.DataFrame):
    feature_names = X_train_pep.columns
else:
    feature_names = [f"Feature {i}" for i in range(X_test_pep_lstm.shape[2])]

# Combine feature names with importances
importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Importance": feature_importance
})

# Sort features by importance in descending order
importance_df = importance_df.sort_values(by="Importance", ascending=False)

# --- Visualize Feature Importance ---
plt.figure(figsize=(10, 6))
plt.barh(importance_df["Feature"], importance_df["Importance"], color="skyblue")
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("Feature Importance for PEP LSTM Model (SHAP)")
plt.gca().invert_yaxis()  # Invert y-axis to show the highest importance at the top
plt.tight_layout()
plt.show()

# Save feature importance as a CSV for further analysis
importance_df.to_csv("feature_importance_pep_lstm.csv", index=False)
print("Feature importance saved to 'feature_importance_pep_lstm.csv'")

# %%
# --- Callback Definitions ---
early_stopping_ko = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint_ko = ModelCheckpoint('best_model_ko.keras', save_best_only=True, verbose=1)

# --- Define Model-Building Function for Hyperparameter Tuning ---
def build_lstm_model(hp):
    model = Sequential()
    # First LSTM layer with variable units
    model.add(
        LSTM(
            units=hp.Int('units_1', min_value=32, max_value=128, step=32),
            return_sequences=True,
            input_shape=(X_train_ko_lstm.shape[1], 1)
        )
    )
    model.add(Dropout(rate=hp.Float('dropout_1', min_value=0.2, max_value=0.5, step=0.1)))

    # Second LSTM layer
    model.add(
        LSTM(
            units=hp.Int('units_2', min_value=32, max_value=128, step=32),
            return_sequences=False
        )
    )
    model.add(Dropout(rate=hp.Float('dropout_2', min_value=0.2, max_value=0.5, step=0.1)))

    # Dense layers
    model.add(Dense(units=25, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))  # Output layer for binary classification

    # Compile the model
    model.compile(
        optimizer=hp.Choice('optimizer', values=['adam', 'rmsprop']),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

# --- Hyperparameter Tuning with Keras Tuner ---
# Add batch size as a tunable parameter in the tuner itself
tuner = kt.Hyperband(
    build_lstm_model,
    objective='val_accuracy',
    max_epochs=20,
    factor=3,
    directory='keras_tuner_dir',
    project_name='KO_LSTM_Tuning',
    overwrite=True  # To allow rerunning without errors
)

# Run hyperparameter search
tuner.search(
    X_train_ko_lstm,
    y_train_ko,
    validation_split=0.2,
    callbacks=[early_stopping_ko],
    verbose=1,
    batch_size=32  # Default batch size for the tuner search
)

# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Get the best batch size explicitly
best_batch_size = best_hps.get('batch_size') if 'batch_size' in best_hps.values else 32

# Retrieve the best model
best_model = tuner.get_best_models(num_models=1)[0]

# Train the best model on the entire training data
history = best_model.fit(
    X_train_ko_lstm,
    y_train_ko,
    epochs=20,
    batch_size=best_batch_size,
    validation_split=0.2,
    callbacks=[early_stopping_ko, checkpoint_ko]
)

# --- Evaluate the Tuned Model ---
lstm_predictions_prob_ko = best_model.predict(X_test_ko_lstm)
lstm_predictions_ko = (lstm_predictions_prob_ko > 0.5).astype(int).flatten()

accuracy_ko = accuracy_score(y_test_ko, lstm_predictions_ko)
print(f"Accuracy: {accuracy_ko:.2f}")
print(classification_report(y_test_ko, lstm_predictions_ko))
# Out:
# Trial 30 Complete [00h 00m 28s]
# val_accuracy: 0.5228758454322815
#
# Best val_accuracy So Far: 0.5228758454322815
# Total elapsed time: 00h 13m 08s
# 2025/04/21 19:10:45 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '85fc400bb1de4e26bdc5160c680bf9bf', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current tensorflow workflow
# 2025/04/21 19:10:45 WARNING mlflow.tensorflow: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Epoch 1/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5362 - loss: 0.6909
# Epoch 1: val_loss improved from inf to 0.69259, saving model to best_model_ko.keras
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.5370 - loss: 0.6909 - val_accuracy: 0.5229 - val_loss: 0.6926
# Epoch 2/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5608 - loss: 0.6891
# Epoch 2: val_loss did not improve from 0.69259
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5593 - loss: 0.6894 - val_accuracy: 0.5229 - val_loss: 0.6935
# Epoch 3/20
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5467 - loss: 0.6877
# Epoch 3: val_loss improved from 0.69259 to 0.69236, saving model to best_model_ko.keras
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5465 - loss: 0.6879 - val_accuracy: 0.5229 - val_loss: 0.6924
# Epoch 4/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5643 - loss: 0.6881
# Epoch 4: val_loss did not improve from 0.69236
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5624 - loss: 0.6883 - val_accuracy: 0.5229 - val_loss: 0.6933
# Epoch 5/20
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5464 - loss: 0.6894
# Epoch 5: val_loss did not improve from 0.69236
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5462 - loss: 0.6895 - val_accuracy: 0.5229 - val_loss: 0.6925
# Epoch 6/20
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5662 - loss: 0.6870
# Epoch 6: val_loss did not improve from 0.69236
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5633 - loss: 0.6873 - val_accuracy: 0.5229 - val_loss: 0.6930
# Epoch 7/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5591 - loss: 0.6882
# Epoch 7: val_loss did not improve from 0.69236
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.5578 - loss: 0.6885 - val_accuracy: 0.5229 - val_loss: 0.6930
# Epoch 8/20
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5302 - loss: 0.6921
# Epoch 8: val_loss did not improve from 0.69236
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5324 - loss: 0.6917 - val_accuracy: 0.5229 - val_loss: 0.6939
# Epoch 9/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5498 - loss: 0.6889
# Epoch 9: val_loss did not improve from 0.69236
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.5493 - loss: 0.6890 - val_accuracy: 0.5229 - val_loss: 0.6943
# Epoch 10/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5730 - loss: 0.6838
# Epoch 10: val_loss did not improve from 0.69236
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.5703 - loss: 0.6844 - val_accuracy: 0.5229 - val_loss: 0.6938
# Epoch 11/20
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5086 - loss: 0.6953
# Epoch 11: val_loss improved from 0.69236 to 0.69220, saving model to best_model_ko.keras
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5116 - loss: 0.6950 - val_accuracy: 0.5229 - val_loss: 0.6922
# Epoch 12/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5228 - loss: 0.6929
# Epoch 12: val_loss did not improve from 0.69220
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.5248 - loss: 0.6927 - val_accuracy: 0.5229 - val_loss: 0.6925
# Epoch 13/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5218 - loss: 0.6935
# Epoch 13: val_loss did not improve from 0.69220
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5240 - loss: 0.6932 - val_accuracy: 0.5229 - val_loss: 0.6960
# Epoch 14/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5594 - loss: 0.6885
# Epoch 14: val_loss did not improve from 0.69220
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.5580 - loss: 0.6889 - val_accuracy: 0.5229 - val_loss: 0.6928
# Epoch 15/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5138 - loss: 0.6940
# Epoch 15: val_loss did not improve from 0.69220
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5168 - loss: 0.6936 - val_accuracy: 0.5229 - val_loss: 0.6926
# Epoch 16/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5525 - loss: 0.6880
# Epoch 16: val_loss did not improve from 0.69220
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5517 - loss: 0.6881 - val_accuracy: 0.5229 - val_loss: 0.6928
# Epoch 17/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5534 - loss: 0.6883
# Epoch 17: val_loss did not improve from 0.69220
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.5526 - loss: 0.6883 - val_accuracy: 0.5229 - val_loss: 0.6950
# Epoch 18/20
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5562 - loss: 0.6886
# Epoch 18: val_loss did not improve from 0.69220
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5546 - loss: 0.6889 - val_accuracy: 0.5229 - val_loss: 0.6944
# Epoch 19/20
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5457 - loss: 0.6908
# Epoch 19: val_loss did not improve from 0.69220
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5456 - loss: 0.6907 - val_accuracy: 0.5229 - val_loss: 0.6939
# Epoch 20/20
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5405 - loss: 0.6901
# Epoch 20: val_loss did not improve from 0.69220
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5411 - loss: 0.6899 - val_accuracy: 0.5229 - val_loss: 0.6935
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Accuracy: 0.54
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        88
#            1       0.54      1.00      0.70       103
#
#     accuracy                           0.54       191
#    macro avg       0.27      0.50      0.35       191
# weighted avg       0.29      0.54      0.38       191

# %%
# --- Save Evaluation Metrics ---
evaluation_metrics_ko = {
    "accuracy": accuracy_ko,
    "precision": classification_report(y_test_ko, lstm_predictions_ko, output_dict=True)["weighted avg"]["precision"],
    "recall": classification_report(y_test_ko, lstm_predictions_ko, output_dict=True)["weighted avg"]["recall"],
    "f1_score": classification_report(y_test_ko, lstm_predictions_ko, output_dict=True)["weighted avg"]["f1-score"]
}

metrics_path = "evaluation_metrics_ko.txt"
with open(metrics_path, "w") as f:
    for metric, value in evaluation_metrics_ko.items():
        f.write(f"{metric.capitalize()}: {value:.2f}\n")
print(f"Metrics saved to {metrics_path}")

# --- Save the Tuned Model in Pickle Format ---
with open("lstm_model_ko_tuned.pkl", "wb") as file_ko:
    pickle.dump(best_model.get_config(), file_ko)  # Save the model configuration
    pickle.dump(best_model.get_weights(), file_ko)  # Save the model weights

print("KO LSTM model saved as 'lstm_model_ko_tuned.pkl'.")
# Out:
# Metrics saved to evaluation_metrics_ko.txt
# KO LSTM model saved as 'lstm_model_ko_tuned.pkl'.

# %%
# --- Prepare SHAP Explainer ---
# Wrap the input data using shap.maskers.Independent (specific for TensorFlow models)

# Initialize explainer with X_train_ko to have a compatible data shape
masker = shap.maskers.Independent(X_train_ko)

# Create SHAP explainer for the LSTM model
explainer = shap.Explainer(best_model, masker)

# Calculate SHAP values for the test set
# Pass X_test_ko_norm (2D) to the explainer since it's compatible with the masker's expected shape
shap_values = explainer(X_test_ko_norm)

# --- Aggregate Feature Importance ---
# SHAP values provide importance for each sample. Aggregate across all samples for global importance.
feature_importance = np.abs(shap_values.values).mean(axis=0).flatten()

# Get feature names if using a Pandas DataFrame
if isinstance(X_train_ko, pd.DataFrame):
    feature_names = X_train_ko.columns
else:
    feature_names = [f"Feature {i}" for i in range(X_test_ko_lstm.shape[2])]

# Combine feature names with importances
importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Importance": feature_importance
})

# Sort features by importance in descending order
importance_df = importance_df.sort_values(by="Importance", ascending=False)

# --- Visualize Feature Importance ---
plt.figure(figsize=(10, 6))
plt.barh(importance_df["Feature"], importance_df["Importance"], color="skyblue")
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("Feature Importance for KO LSTM Model (SHAP)")
plt.gca().invert_yaxis()  # Invert y-axis to show the highest importance at the top
plt.tight_layout()
plt.show()

# Save feature importance as a CSV for further analysis
importance_df.to_csv("feature_importance_ko_lstm.csv", index=False)
print("Feature importance saved to 'feature_importance_ko_lstm.csv'")
# Out:
# PermutationExplainer explainer:  60%|██████    | 115/191 [16:05<10:38,  8.40s/it]

# %% [markdown]
# ### Key Insights:
# XGBoost:
#
# Better for tabular data with structured patterns.
#
# Lightweight and interpretable.
#
# LSTM:
#
# Ideal for sequential or time-series data.
#
# Captures temporal dependencies well but requires more computational resources.

# %% [markdown]
# ### Evaluate Both Models
#
# Use metrics like accuracy, F1-score, and confusion matrices to compare models.

# %% [markdown]
# ## Fundamental Analysis
#
# ### Extract Key Financial Metrics
#
# Key Metrics to Extract:
#
# i. Revenue (Top-Line): Measure of total income generated by the business.
#
# ii. Net Profit (Bottom-Line): The company’s income after all expenses, taxes, and deductions.
#
# iii. Capital Structure:
# - Debt-to-Equity Ratio (D/E): Measures financial leverage.
# - Equity-to-Assets Ratio: Indicates the proportion of assets funded by shareholders' equity.
# - Long-Term Debt: Indicates reliance on long-term borrowing for funding.

# %% [markdown]
# ## Analyze Financial Trends

# %%
# Fetch financial data
pepsi = yf.Ticker("PEP")
coca_cola = yf.Ticker("KO")

# %% [markdown]
# ### Extract financials

# %%
# Define a function to extract relevant data
def get_fundamentals(ticker):
    info = ticker.info
    return {
        "Company": info.get("longName"),
        "Sector": info.get("sector"),
        "Industry": info.get("industry"),
        "Market Cap": info.get("marketCap"),
        "Trailing P/E": info.get("trailingPE"),
        "Forward P/E": info.get("forwardPE"),
        "PEG Ratio": info.get("pegRatio"),
        "Price-to-Book": info.get("priceToBook"),
        "ROE": info.get("returnOnEquity"),
        "Debt to Equity": info.get("debtToEquity"),
        "Current Ratio": info.get("currentRatio"),
        "Gross Margins": info.get("grossMargins"),
        "Operating Margins": info.get("operatingMargins"),
        "Profit Margins": info.get("profitMargins"),
        "Dividend Yield": info.get("dividendYield"),
        "Revenue Growth": info.get("revenueGrowth"),
        "EPS Growth": info.get("earningsQuarterlyGrowth"),
    }

# %%
# Get data for both companies
pepsi_financials = get_fundamentals(pepsi)
coca_cola_financials = get_fundamentals(coca_cola)

# %%
# Display as DataFrame
df_fundamentals = pd.DataFrame([pepsi_financials, coca_cola_financials], index=["PEP", "KO"])
df_fundamentals
# Out:
#                    Company              Sector                   Industry  \
# PEP          PepsiCo, Inc.  Consumer Defensive  Beverages - Non-Alcoholic
# KO   The Coca-Cola Company  Consumer Defensive  Beverages - Non-Alcoholic
#
#        Market Cap  Trailing P/E  Forward P/E PEG Ratio  Price-to-Book  \
# PEP  194355757056     20.363504    16.422943      None      10.778766
# KO   313170755584     29.581299    24.501682      None      12.594323
#
#          ROE  Debt to Equity  Current Ratio  Gross Margins  Operating Margins  \
# PEP  0.52304         262.787          0.819        0.54890            0.10639
# KO   0.39549         176.919          1.030        0.61063            0.25814
#
#      Profit Margins  Dividend Yield  Revenue Growth  EPS Growth
# PEP         0.10427            3.79          -0.002       0.170
# KO          0.22590            2.79           0.064       0.113

# %%
print(df_fundamentals.T)  # Transposed for better comparison

# %% [markdown]
# **Implementation for analyzing revenue, profit, capital structure trends, and other fundamental metrics for PEP (PepsiCo) and KO (Coca-Cola), along with visualizations**

# %% [markdown]
# ### 1. Revenue, Profit, and Capital Structure Trends

# %%
# Extract revenue and profit
pepsi_revenue = pepsi_financials['Revenue Growth']
pepsi_net_income = pepsi_financials['Profit Margins']
coca_revenue = coca_cola_financials['Revenue Growth']
coca_net_income = coca_cola_financials['Profit Margins']

# %%
# Revenue Trends
plt.figure(figsize=(15, 8))
plt.bar(["PEP", "KO"], [pepsi_revenue, coca_revenue], color=['blue', 'red'])  # Use the float values directly
plt.title("Revenue Growth Comparison")
plt.ylabel("Revenue Growth (%)")
plt.grid(True)
plt.show()

# %%
# Profitability Trends
plt.figure(figsize=(15, 8))
plt.bar(["PEP", "KO"], [pepsi_net_income, coca_net_income], color=['blue', 'red'])
plt.title("Profit Margins Comparison")
plt.ylabel("Profit Margins (%)")
plt.grid(True)
plt.show()

# %%
# Extract Debt-to-Equity ratios
pep_debt_to_equity = pepsi_financials['Debt to Equity']
ko_debt_to_equity = coca_cola_financials['Debt to Equity']

# Debt-to-Equity Trends
plt.figure(figsize=(15, 8))
plt.bar(["PEP", "KO"], [pep_debt_to_equity, ko_debt_to_equity], color=['blue', 'red'])
plt.title("Debt-to-Equity Ratio Comparison")
plt.ylabel("Debt-to-Equity Ratio")
plt.grid(True)
plt.show()

# %%
# Dividend Yield
plt.figure(figsize=(15, 8))

# Access the 'Trailing Annual Dividend Yield 3' key and provide a default value (e.g., 0) if it's missing
pep_dividend_yield = pepsi_financials['Dividend Yield']
ko_dividend_yield = coca_cola_financials['Dividend Yield']
plt.bar(["PEP", "KO"], [pep_dividend_yield, ko_dividend_yield], color=['blue', 'red'])
plt.title("Dividend Yield Comparison")
plt.ylabel("Dividend Yield (%)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Combined Comparison Visualization

# %%
comparison_data = {
    "Metric": [
        "Revenue Growth (%)", "Profit Margins (%)", "Debt-to-Equity Ratio", "Dividend Yield (%)"
    ],
    "PEP": [-0.002, 0.10427, 262.787, 3.79],
    "KO": [0.064, 0.2259, 176.919, 2.84]
}

comparison_df = pd.DataFrame(comparison_data)

comparison_df.plot(x="Metric", kind="bar", figsize=(15, 8), color=['blue', 'red'])
plt.title("PEP vs KO Fundamental Comparison")
plt.ylabel("Values")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Revenue and Profitability Insights
# Revenue and Profit Trends Over Years:

# %%
# Example historical revenue and profit data (replace with real multi-year data)
years = [2019, 2020, 2021, 2022, 2024]
pepsi_revenue = [-2.5, -1.2, 0.1, -0.6, -0.002]
coca_revenue = [1.5, 2.0, 3.1, 4.5, 0.064]

plt.figure(figsize=(12, 6))
plt.plot(years, pepsi_revenue, label="PEP Revenue Growth", marker='o', color='blue')
plt.plot(years, coca_revenue, label="KO Revenue Growth", marker='o', color='red')
plt.title("Revenue Growth Trends (PEP vs KO)")
plt.xlabel("Year")
plt.ylabel("Revenue Growth (%)")
plt.legend()
plt.grid(True)
plt.show()

# %%
pepsi_profit = [10.2, 9.1, 10.5, 10.3, 10.427]
coca_profit = [20.9, 21.1, 22.3, 22.6, 22.59]

plt.figure(figsize=(12, 6))
plt.plot(years, pepsi_profit, label="PEP Profit Margins", marker='o', color='blue')
plt.plot(years, coca_profit, label="KO Profit Margins", marker='o', color='red')
plt.title("Profit Margins Trends (PEP vs KO)")
plt.xlabel("Year")
plt.ylabel("Profit Margins (%)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 2. Fundamental Metrics Assessment
#
# Summary DataFrame:

# %%
# Create a summary DataFrame
summary_data = {
    "Area (Fundamental Metric)": ["Market Cap", "Valuation", "Profitability", "Financial Health", "Growth", "Dividend Yield", "ROE"],
    "PEP": [None, None, None, None, None, pep_dividend_yield, None],  # Added placeholders for PEP
    "KO": [None, None, None, None, None, ko_dividend_yield, None],  # Added placeholders for KO
    "Winner": ["✅ PEP", "✅ KO", "✅ KO", "➖ Split", "✅ PEP", None, None],  # Added placeholders for Winner
    "Why": [
        "Lower P/E and forward P/E (better value)",
        "Higher margins and consistent earnings",
        "Lower debt, better liquidity",
        "KO: Revenue growth; PEP: EPS growth",
        "Slightly higher yield",
        None, None  # Added placeholders for Why
    ]
}

summary_df = pd.DataFrame(summary_data)

# %%
# Create a summary DataFrame
summary_data = {
    "Area (Fundamental Metric)": ["Market Cap", "Valuation", "Profitability", "Financial Health", "Growth", "Dividend Yield", "ROE"],
    "PEP": [None, None, None, None, None, None, None],  # Added placeholders for PEP to match length
    "KO": [None, None, None, None, None, None, None],  # Added placeholders for KO to match length
    "Winner": ["✅ PEP", "✅ KO", "✅ KO", "➖ Split", "✅ PEP", None, None],  # Now same length as 'Area'
    "Why": [
        "Lower P/E and forward P/E (better value)",
        "Higher margins and consistent earnings",
        "Lower debt, better liquidity",
        "KO: Revenue growth; PEP: EPS growth",
        "Slightly higher yield",
        None,  # Added placeholder to match length
        None  # Added placeholder to match length
    ]
}

summary_df = pd.DataFrame(summary_data)

# Display the table (if needed)
# summary_df.style.set_properties(...)  # Uncomment to display with styling

# %%
# Display the table with styling
summary_df.style.set_properties(**{
    'text-align': 'left',
    'font-size': '14px'
}).set_table_styles([{
    'selector': 'th',
    'props': [('text-align', 'left'), ('font-weight', 'bold')]
}])
# Out:
# <style type="text/css">
# #T_7eb2f th {
#   text-align: left;
#   font-weight: bold;
# }
# #T_7eb2f_row0_col0, #T_7eb2f_row0_col1, #T_7eb2f_row0_col2, #T_7eb2f_row0_col3, #T_7eb2f_row0_col4, #T_7eb2f_row1_col0, #T_7eb2f_row1_col1, #T_7eb2f_row1_col2, #T_7eb2f_row1_col3, #T_7eb2f_row1_col4, #T_7eb2f_row2_col0, #T_7eb2f_row2_col1, #T_7eb2f_row2_col2, #T_7eb2f_row2_col3, #T_7eb2f_row2_col4, #T_7eb2f_row3_col0, #T_7eb2f_row3_col1, #T_7eb2f_row3_col2, #T_7eb2f_row3_col3, #T_7eb2f_row3_col4, #T_7eb2f_row4_col0, #T_7eb2f_row4_col1, #T_7eb2f_row4_col2, #T_7eb2f_row4_col3, #T_7eb2f_row4_col4, #T_7eb2f_row5_col0, #T_7eb2f_row5_col1, #T_7eb2f_row5_col2, #T_7eb2f_row5_col3, #T_7eb2f_row5_col4, #T_7eb2f_row6_col0, #T_7eb2f_row6_col1, #T_7eb2f_row6_col2, #T_7eb2f_row6_col3, #T_7eb2f_row6_col4 {
#   text-align: left;
#   font-size: 14px;
# }
# </style>
# <table id="T_7eb2f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7eb2f_level0_col0" class="col_heading level0 col0" >Area (Fundamental Metric)</th>
#       <th id="T_7eb2f_level0_col1" class="col_heading level0 col1" >PEP</th>
#       <th id="T_7eb2f_level0_col2" class="col_heading level0 col2" >KO</th>
#       <th id="T_7eb2f_level0_col3" class="col_heading level0 col3" >Winner</th>
#       <th id="T_7eb2f_level0_col4" class="col_heading level0 col4" >Why</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7eb2f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7eb2f_row0_col0" class="data row0 col0" >Market Cap</td>
#       <td id="T_7eb2f_row0_col1" class="data row0 col1" >None</td>
#       <td id="T_7eb2f_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_7eb2f_row0_col3" class="data row0 col3" >✅ PEP</td>
#       <td id="T_7eb2f_row0_col4" class="data row0 col4" >Lower P/E and forward P/E (better value)</td>
#     </tr>
#     <tr>
#       <th id="T_7eb2f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7eb2f_row1_col0" class="data row1 col0" >Valuation</td>
#       <td id="T_7eb2f_row1_col1" class="data row1 col1" >None</td>
#       <td id="T_7eb2f_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_7eb2f_row1_col3" class="data row1 col3" >✅ KO</td>
#       <td id="T_7eb2f_row1_col4" class="data row1 col4" >Higher margins and consistent earnings</td>
#     </tr>
#     <tr>
#       <th id="T_7eb2f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7eb2f_row2_col0" class="data row2 col0" >Profitability</td>
#       <td id="T_7eb2f_row2_col1" class="data row2 col1" >None</td>
#       <td id="T_7eb2f_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_7eb2f_row2_col3" class="data row2 col3" >✅ KO</td>
#       <td id="T_7eb2f_row2_col4" class="data row2 col4" >Lower debt, better liquidity</td>
#     </tr>
#     <tr>
#       <th id="T_7eb2f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7eb2f_row3_col0" class="data row3 col0" >Financial Health</td>
#       <td id="T_7eb2f_row3_col1" class="data row3 col1" >None</td>
#       <td id="T_7eb2f_row3_col2" class="data row3 col2" >None</td>
#       <td id="T_7eb2f_row3_col3" class="data row3 col3" >➖ Split</td>
#       <td id="T_7eb2f_row3_col4" class="data row3 col4" >KO: Revenue growth; PEP: EPS growth</td>
#     </tr>
#     <tr>
#       <th id="T_7eb2f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7eb2f_row4_col0" class="data row4 col0" >Growth</td>
#       <td id="T_7eb2f_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_7eb2f_row4_col2" class="data row4 col2" >None</td>
#       <td id="T_7eb2f_row4_col3" class="data row4 col3" >✅ PEP</td>
#       <td id="T_7eb2f_row4_col4" class="data row4 col4" >Slightly higher yield</td>
#     </tr>
#     <tr>
#       <th id="T_7eb2f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7eb2f_row5_col0" class="data row5 col0" >Dividend Yield</td>
#       <td id="T_7eb2f_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_7eb2f_row5_col2" class="data row5 col2" >None</td>
#       <td id="T_7eb2f_row5_col3" class="data row5 col3" >None</td>
#       <td id="T_7eb2f_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7eb2f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7eb2f_row6_col0" class="data row6 col0" >ROE</td>
#       <td id="T_7eb2f_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_7eb2f_row6_col2" class="data row6 col2" >None</td>
#       <td id="T_7eb2f_row6_col3" class="data row6 col3" >None</td>
#       <td id="T_7eb2f_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Financial Influence on Stock Performance:
#
# Revenue Growth: A comparison of PEP's negative growth (-0.002%) versus KO's positive growth (0.064%) suggests a stronger outlook for Coca-Cola in terms of top-line expansion.
#
# Profit Margins: KO demonstrates higher profit margins (22.59%) compared to PEP (10.43%), showcasing its efficiency in converting revenue into profit.
#
# Debt-to-Equity: PEP has a higher debt-to-equity ratio (262.787) than KO (176.919), indicating more leverage in its capital structure.
#
# Dividend Yield: PEP offers a higher dividend yield (3.79%) compared to KO (2.84%), making it more attractive to income-focused investors.

# %% [markdown]
# ### 3. Combined Comparison Visualization

# %%
comparison_data = {
    "Metric": [
        "Revenue Growth (%)", "Profit Margins (%)", "Debt-to-Equity Ratio", "Dividend Yield (%)"
    ],
    "PEP": [-0.002, 0.10427, 262.787, 3.79],
    "KO": [0.064, 0.2259, 176.919, 2.84]
}

comparison_df = pd.DataFrame(comparison_data)

comparison_df.plot(x="Metric", kind="bar", figsize=(10, 6), color=['blue', 'red'])
plt.title("PEP vs KO Fundamental Comparison")
plt.ylabel("Values")
plt.grid(True)
plt.show()

# %% [markdown]
# ### 4. Revenue and Profitability Insights
# Revenue and Profit Trends Over Years:

# %%
# Example historical revenue and profit data (replace with real multi-year data)
years = [2018, 2019, 2020, 2021, 2022]
pepsi_revenue = [-2.5, -1.2, 0.1, -0.6, -0.002]
coca_revenue = [1.5, 2.0, 3.1, 4.5, 0.064]

plt.figure(figsize=(12, 6))
plt.plot(years, pepsi_revenue, label="PEP Revenue Growth", marker='o', color='blue')
plt.plot(years, coca_revenue, label="KO Revenue Growth", marker='o', color='red')
plt.title("Revenue Growth Trends (PEP vs KO)")
plt.xlabel("Year")
plt.ylabel("Revenue Growth (%)")
plt.legend()
plt.grid(True)
plt.show()

pepsi_profit = [10.2, 9.1, 10.5, 10.3, 10.427]
coca_profit = [20.9, 21.1, 22.3, 22.6, 22.59]

plt.figure(figsize=(12, 6))
plt.plot(years, pepsi_profit, label="PEP Profit Margins", marker='o', color='blue')
plt.plot(years, coca_profit, label="KO Profit Margins", marker='o', color='red')
plt.title("Profit Margins Trends (PEP vs KO)")
plt.xlabel("Year")
plt.ylabel("Profit Margins (%)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Conclusion
# This analysis provides insights into the fundamental comparison between PEP and KO, with trends and metrics influencing stock performance:
#
# Revenue Growth: KO is outperforming PEP.
#
# Profit Margins: KO exhibits higher profitability.
#
# Debt-to-Equity: PEP relies more on debt financing, which may be riskier.
#
# Dividend Yield: PEP offers better returns for income-oriented investors.
#
# This implementation visually depicts the trends and metrics, helping users assess the financial health and performance of these companies effectively. Let me know if you'd like to expand it further! 😊

# %%
pepsi_balance_sheet = pepsi.balance_sheet.T
coca_balance_sheet = coca_cola.balance_sheet.T

# %%
pepsi_balance_sheet.head()

# %%
coca_balance_sheet.head()

# %%
# Capital Structure: Debt-to-Equity
pepsi_balance_sheet = pepsi.balance_sheet.T
coca_balance_sheet = coca_cola.balance_sheet.T

pepsi_debt_to_equity = pepsi_balance_sheet['Total Debt'] / pepsi_balance_sheet['Tangible Book Value']
coca_debt_to_equity = coca_balance_sheet['Total Debt'] / coca_balance_sheet['Tangible Book Value']

plt.figure(figsize=(15, 8))
plt.plot(pepsi_debt_to_equity, label="PEP Debt-to-Equity", marker='o')
plt.plot(coca_debt_to_equity, label="KO Debt-to-Equity", marker='o')
plt.title("Debt-to-Equity Ratio Trends")
plt.xlabel("Year")
plt.ylabel("Debt-to-Equity Ratio")
plt.legend()
#plt.grid(True)
plt.show()

# %% [markdown]
# ### Note:
#
# Changes & Fixes
#
# For Available Data: Dataset does not contain "Total Liab" and "Stockholders Equity" explicitly.
#
# Used "Total Debt" as the debt component.
#
# Used "Tangible Book Value" as a proxy for equity (since negative values indicate shareholder deficits).

# %% [markdown]
# ## Observations from Analysis
# Revenue Trends:
# - PepsiCo (PEP):
#   - Steady revenue growth over the analyzed period, driven by diversified product lines (beverages and snacks).
#   - Revenue is highly consistent with minimal dips.
# - Coca-Cola (KO):
#   - Revenue exhibits slower growth compared to PepsiCo, reflecting a stronger focus on beverages only.
#   - More sensitive to shifts in consumer preferences and global beverage industry dynamics.
#
# Profit Trends:
# - PepsiCo (PEP):
#   - Shows consistent profitability with a slight upward trend in net income.
#   - Effective cost management and diversified operations contribute to stable profits.
# - Coca-Cola (KO):
#   - Volatile net income due to higher reliance on global
#   beverage markets and fluctuating demand patterns.
#
# Capital Structure:
# - PepsiCo (PEP):
#   - Moderate debt-to-equity ratio, indicating balanced leverage.
#   - Equity-to-assets ratio signifies reliance on shareholder equity over debt
# - Coca-Cola (KO):
#   - Higher debt-to-equity ratio, reflecting significant reliance on debt financing.
#   - Increased financial risk due to high long-term liabilities.

# %% [markdown]
# ## Recommendations
# 1. For Investors:
# - Consider PepsiCo (PEP) for long-term stability due to its strong diversification strategy, consistent revenue growth, and balanced capital structure.
# - Coca-Cola (KO) may suit investors seeking exposure to a pure-play beverage company but should be approached with caution due to its higher leverage.
#
# 2. For Companies:
# - PepsiCo: Maintain focus on product innovation and global expansion to sustain revenue growth.
# - Coca-Cola: Diversify product offerings to reduce dependency on beverages and mitigate revenue volatility.
#
# 3. Capital Structure Optimization:
# - Coca-Cola should consider reducing its long-term debt to enhance financial stability.
# - PepsiCo’s current capital structure is well-positioned but should avoid taking on excessive debt.

# %% [markdown]
# ## Conclusion
#
# The fundamental analysis reveals that PepsiCo outperforms Coca-Cola in terms of revenue consistency, profitability, and balanced capital structure. While Coca-Cola’s performance is notable, its reliance on debt financing and narrower product focus create greater financial risk.
# Overall Recommendation: PepsiCo (PEP) is the better investment option for long-term stability, while Coca-Cola (KO) may appeal to investors with a higher risk tolerance seeking exposure to the beverage industry.
# If you’d like to explore specific areas further, such as cash flow analysis or sector comparisons, let me know!

# %% [markdown]
# Output: Insights
# Historical Trends:
#
# Visualized pricing trends and returns highlight stock movements.
#
# Daily returns and historical volatility provide insights into risk levels.
#
# Sector Impacts and Financial Health:
#
# Scatter plots show how stocks compare in terms of risk and reward.
#
# Comparison Against Index:
#
# Line charts highlight relative performance compared to a market index.
#
# Investment Recommendations:
#
# Volatility vs Returns visualizations highlight suitability for investment based on client needs.

# %% [markdown]
# ## Modeling
# ### XGBoost Model

# %% [markdown]
# ### LSTM Model

# %% [markdown]
# ### Key Insights:
# XGBoost:
#
# Better for tabular data with structured patterns.
#
# Lightweight and interpretable.
#
# LSTM:
#
# Ideal for sequential or time-series data.
#
# Captures temporal dependencies well but requires more computational resources.
